# %% [markdown]
# # AI translation validation for Ubuntu - Data collection
#
# Use of Weblate API to automatically collect, store and update desired translations on the website Weblate.

# %% [markdown]
# # Importing annex useful functions

# %%
# Personal libraries
import importlib
import collector
from collector import Collector

# %%
importlib.reload(collector)
from collector import Collector
collector = Collector()

# %% [markdown]
# # Weblate projects
# Given a list of projects (or of keywords contained in the desired project names), one can download all its translations, in all languages using the function ``get_all_translations`` function :

# %%
# list of weblate apis and the associated desired project. when ALL : all the projects will be downloaded
wanted_projects = ["ubuntu", "debian"]

wanted_projects = ["debian handbook"]
collector.get_all_translations("https://hosted.weblate.org/api/", "wlu_F8mRZZeJG9OZ4Y3NfGW6lakufaKJPu7IQFwI", wanted_projects)

# %% [markdown]
# # openSUSE translations
# openSUSE uses its own translation website, but it is also based on the Weblate API. Hence, it is possible to quickly adapt the previous code to collect all the translation of the software, that are numerous.

# %%
# list of weblate apis and the associated desired project. when ALL : all the projects will be downloaded
wanted_projects = ["ALL"]
collector.get_all_translations("https://l10n.opensuse.org/api/", "", wanted_projects)

# %% [markdown]
# # Ubuntu Launchpad translations
# Ubuntu translations are available on Launchpad, that allows to download a .zip file with all translations. We will use this way to download them, and we will save the update time in case an update is required. <br>
# **Note :** the dataset could be extended with previous versions of Ubuntu, that are also available on Launchpad.

# %%
collector.get_ubuntu_translation("https://translations.launchpad.net/ubuntu/noble/+translations")
# Out:
# Archive name: ubuntu-noble-translations.tar.gz
# ubuntu-noble-translations.tar.gz already downloaded.
# Exploring  rosetta-noble
# Exploring  rosetta-noble/af
# Exploring  rosetta-noble/af/LC_MESSAGES
# Created/Updated : ubuntu_by_language\af\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/sq
# Exploring  rosetta-noble/sq/LC_MESSAGES
# Created/Updated : ubuntu_by_language\sq\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/am
# Exploring  rosetta-noble/am/LC_MESSAGES
# Created/Updated : ubuntu_by_language\am\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/ar
# Exploring  rosetta-noble/ar/LC_MESSAGES
# ubuntu_by_language\ar\LC_MESSAGES-adduser.csv is empty.
# Exploring  rosetta-noble/an
# Exploring  rosetta-noble/an/LC_MESSAGES
# ubuntu_by_language\an\LC_MESSAGES-adduser.csv is empty.
# Exploring  rosetta-noble/ast
# Exploring  rosetta-noble/ast/LC_MESSAGES
# Created/Updated : ubuntu_by_language\ast\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/eu
# Exploring  rosetta-noble/eu/LC_MESSAGES
# Created/Updated : ubuntu_by_language\eu\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/be
# Exploring  rosetta-noble/be/LC_MESSAGES
# Created/Updated : ubuntu_by_language\be\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/bn
# Exploring  rosetta-noble/bn/LC_MESSAGES
# Created/Updated : ubuntu_by_language\bn\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/bs
# Exploring  rosetta-noble/bs/LC_MESSAGES
# Created/Updated : ubuntu_by_language\bs\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/bg
# Exploring  rosetta-noble/bg/LC_MESSAGES
# Created/Updated : ubuntu_by_language\bg\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/my
# Exploring  rosetta-noble/my/LC_MESSAGES
# Created/Updated : ubuntu_by_language\my\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/ca
# Exploring  rosetta-noble/ca/LC_MESSAGES
# Created/Updated : ubuntu_by_language\ca\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/ce
# Exploring  rosetta-noble/ce/LC_MESSAGES
# ubuntu_by_language\ce\LC_MESSAGES-adduser.csv is empty.
# Exploring  rosetta-noble/cs
# Exploring  rosetta-noble/cs/LC_MESSAGES
# Created/Updated : ubuntu_by_language\cs\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/da
# Exploring  rosetta-noble/da/LC_MESSAGES
# Created/Updated : ubuntu_by_language\da\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/dsb
# Exploring  rosetta-noble/dsb/LC_MESSAGES
# Created/Updated : ubuntu_by_language\dsb\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/nl
# Exploring  rosetta-noble/nl/LC_MESSAGES
# Created/Updated : ubuntu_by_language\nl\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/en
# Exploring  rosetta-noble/en/LC_MESSAGES
# ubuntu_by_language\en\LC_MESSAGES-adduser.csv is empty.
# Exploring  rosetta-noble/eo
# Exploring  rosetta-noble/eo/LC_MESSAGES
# Created/Updated : ubuntu_by_language\eo\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/et
# Exploring  rosetta-noble/et/LC_MESSAGES
# Created/Updated : ubuntu_by_language\et\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/fi
# Exploring  rosetta-noble/fi/LC_MESSAGES
# Created/Updated : ubuntu_by_language\fi\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/fr
# Exploring  rosetta-noble/fr/LC_MESSAGES
# Created/Updated : ubuntu_by_language\fr\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/de
# Exploring  rosetta-noble/de/LC_MESSAGES
# Created/Updated : ubuntu_by_language\de\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/gl
# Exploring  rosetta-noble/gl/LC_MESSAGES
# Created/Updated : ubuntu_by_language\gl\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/el
# Exploring  rosetta-noble/el/LC_MESSAGES
# Created/Updated : ubuntu_by_language\el\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/gu
# Exploring  rosetta-noble/gu/LC_MESSAGES
# Created/Updated : ubuntu_by_language\gu\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/he
# Exploring  rosetta-noble/he/LC_MESSAGES
# Created/Updated : ubuntu_by_language\he\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/hi
# Exploring  rosetta-noble/hi/LC_MESSAGES
# Created/Updated : ubuntu_by_language\hi\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/hu
# Exploring  rosetta-noble/hu/LC_MESSAGES
# Created/Updated : ubuntu_by_language\hu\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/is
# Exploring  rosetta-noble/is/LC_MESSAGES
# Created/Updated : ubuntu_by_language\is\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/id
# Exploring  rosetta-noble/id/LC_MESSAGES
# Created/Updated : ubuntu_by_language\id\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/it
# Exploring  rosetta-noble/it/LC_MESSAGES
# Created/Updated : ubuntu_by_language\it\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/ja
# Exploring  rosetta-noble/ja/LC_MESSAGES
# Created/Updated : ubuntu_by_language\ja\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/kl
# Exploring  rosetta-noble/kl/LC_MESSAGES
# ubuntu_by_language\kl\LC_MESSAGES-adduser.csv is empty.
# Exploring  rosetta-noble/kn
# Exploring  rosetta-noble/kn/LC_MESSAGES
# Created/Updated : ubuntu_by_language\kn\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/km
# Exploring  rosetta-noble/km/LC_MESSAGES
# ubuntu_by_language\km\LC_MESSAGES-adduser.csv is empty.
# Exploring  rosetta-noble/ko
# Exploring  rosetta-noble/ko/LC_MESSAGES
# Created/Updated : ubuntu_by_language\ko\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/ku
# Exploring  rosetta-noble/ku/LC_MESSAGES
# Created/Updated : ubuntu_by_language\ku\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/lo
# Exploring  rosetta-noble/lo/LC_MESSAGES
# ubuntu_by_language\lo\LC_MESSAGES-adduser.csv is empty.
# Exploring  rosetta-noble/lv
# Exploring  rosetta-noble/lv/LC_MESSAGES
# Created/Updated : ubuntu_by_language\lv\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/lt
# Exploring  rosetta-noble/lt/LC_MESSAGES
# Created/Updated : ubuntu_by_language\lt\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/ms
# Exploring  rosetta-noble/ms/LC_MESSAGES
# Created/Updated : ubuntu_by_language\ms\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/mn
# Exploring  rosetta-noble/mn/LC_MESSAGES
# Created/Updated : ubuntu_by_language\mn\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/nds
# Exploring  rosetta-noble/nds/LC_MESSAGES
# ubuntu_by_language\nds\LC_MESSAGES-adduser.csv is empty.
# Exploring  rosetta-noble/nn
# Exploring  rosetta-noble/nn/LC_MESSAGES
# Created/Updated : ubuntu_by_language\nn\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/nb
# Exploring  rosetta-noble/nb/LC_MESSAGES
# Created/Updated : ubuntu_by_language\nb\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/oc
# Exploring  rosetta-noble/oc/LC_MESSAGES
# Created/Updated : ubuntu_by_language\oc\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/om
# Exploring  rosetta-noble/om/LC_MESSAGES
# Created/Updated : ubuntu_by_language\om\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/fa
# Exploring  rosetta-noble/fa/LC_MESSAGES
# Created/Updated : ubuntu_by_language\fa\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/pl
# Exploring  rosetta-noble/pl/LC_MESSAGES
# Created/Updated : ubuntu_by_language\pl\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/pt
# Exploring  rosetta-noble/pt/LC_MESSAGES
# Created/Updated : ubuntu_by_language\pt\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/ps
# Exploring  rosetta-noble/ps/LC_MESSAGES
# ubuntu_by_language\ps\LC_MESSAGES-adduser.csv is empty.
# Exploring  rosetta-noble/ro
# Exploring  rosetta-noble/ro/LC_MESSAGES
# Created/Updated : ubuntu_by_language\ro\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/ru
# Exploring  rosetta-noble/ru/LC_MESSAGES
# Created/Updated : ubuntu_by_language\ru\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/sr
# Exploring  rosetta-noble/sr/LC_MESSAGES
# Created/Updated : ubuntu_by_language\sr\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/sco
# Exploring  rosetta-noble/sco/LC_MESSAGES
# Created/Updated : ubuntu_by_language\sco\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/hr
# Exploring  rosetta-noble/hr/LC_MESSAGES
# Created/Updated : ubuntu_by_language\hr\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/sk
# Exploring  rosetta-noble/sk/LC_MESSAGES
# Created/Updated : ubuntu_by_language\sk\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/sl
# Exploring  rosetta-noble/sl/LC_MESSAGES
# Created/Updated : ubuntu_by_language\sl\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/es
# Exploring  rosetta-noble/es/LC_MESSAGES
# Created/Updated : ubuntu_by_language\es\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/sv
# Exploring  rosetta-noble/sv/LC_MESSAGES
# Created/Updated : ubuntu_by_language\sv\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/ta
# Exploring  rosetta-noble/ta/LC_MESSAGES
# ubuntu_by_language\ta\LC_MESSAGES-adduser.csv is empty.
# Exploring  rosetta-noble/te
# Exploring  rosetta-noble/te/LC_MESSAGES
# Created/Updated : ubuntu_by_language\te\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/tg
# Exploring  rosetta-noble/tg/LC_MESSAGES
# ubuntu_by_language\tg\LC_MESSAGES-adduser.csv is empty.
# Exploring  rosetta-noble/tl
# Exploring  rosetta-noble/tl/LC_MESSAGES
# ubuntu_by_language\tl\LC_MESSAGES-adduser.csv is empty.
# Exploring  rosetta-noble/th
# Exploring  rosetta-noble/th/LC_MESSAGES
# Created/Updated : ubuntu_by_language\th\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/bo
# Exploring  rosetta-noble/bo/LC_MESSAGES
# ubuntu_by_language\bo\LC_MESSAGES-adduser.csv is empty.
# Exploring  rosetta-noble/tr
# Exploring  rosetta-noble/tr/LC_MESSAGES
# Created/Updated : ubuntu_by_language\tr\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/ug
# Exploring  rosetta-noble/ug/LC_MESSAGES
# Created/Updated : ubuntu_by_language\ug\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/uk
# Exploring  rosetta-noble/uk/LC_MESSAGES
# Created/Updated : ubuntu_by_language\uk\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/ur
# Exploring  rosetta-noble/ur/LC_MESSAGES
# Created/Updated : ubuntu_by_language\ur\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/vi
# Exploring  rosetta-noble/vi/LC_MESSAGES
# Created/Updated : ubuntu_by_language\vi\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/zh_HK
# Exploring  rosetta-noble/zh_HK/LC_MESSAGES
# Created/Updated : ubuntu_by_language\zh_HK\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/en_US
# Exploring  rosetta-noble/en_US/LC_MESSAGES
# ubuntu_by_language\en_US\LC_MESSAGES-adduser.csv is empty.
# Exploring  rosetta-noble/pt_BR
# Exploring  rosetta-noble/pt_BR/LC_MESSAGES
# Created/Updated : ubuntu_by_language\pt_BR\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/en_GB
# Exploring  rosetta-noble/en_GB/LC_MESSAGES
# Created/Updated : ubuntu_by_language\en_GB\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/fr_CA
# Exploring  rosetta-noble/fr_CA/LC_MESSAGES
# ubuntu_by_language\fr_CA\LC_MESSAGES-adduser.csv is empty.
# Exploring  rosetta-noble/en_AU
# Exploring  rosetta-noble/en_AU/LC_MESSAGES
# Created/Updated : ubuntu_by_language\en_AU\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/zh_TW
# Exploring  rosetta-noble/zh_TW/LC_MESSAGES
# Created/Updated : ubuntu_by_language\zh_TW\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/zh_CN
# Exploring  rosetta-noble/zh_CN/LC_MESSAGES
# Created/Updated : ubuntu_by_language\zh_CN\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/es_ES
# Exploring  rosetta-noble/es_ES/LC_MESSAGES
# ubuntu_by_language\es_ES\LC_MESSAGES-adduser.csv is empty.
# Exploring  rosetta-noble/de_DE
# Exploring  rosetta-noble/de_DE/LC_MESSAGES
# Created/Updated : ubuntu_by_language\de_DE\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/en_CA
# Exploring  rosetta-noble/en_CA/LC_MESSAGES
# Created/Updated : ubuntu_by_language\en_CA\LC_MESSAGES-adduser.csv
# Exploring  rosetta-noble/miq
# Exploring  rosetta-noble/miq/LC_MESSAGES
# ubuntu_by_language\miq\LC_MESSAGES-adduser.csv is empty.
# Exploring  rosetta-noble/ta_LK
# Exploring  rosetta-noble/ta_LK/LC_MESSAGES
# ubuntu_by_language\ta_LK\LC_MESSAGES-adduser.csv is empty.
# Created/Updated : ubuntu_by_language\af\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\sq\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\ar\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\ast\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\eu\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\be\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\bn\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\bs\LC_MESSAGES-alsa-utils.csv
# Exploring  rosetta-noble/br
# Exploring  rosetta-noble/br/LC_MESSAGES
# Created/Updated : ubuntu_by_language\br\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\bg\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\ca\LC_MESSAGES-alsa-utils.csv
# ubuntu_by_language\ce\LC_MESSAGES-alsa-utils.csv is empty.
# Created/Updated : ubuntu_by_language\cs\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\da\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\nl\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\fi\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\fr\LC_MESSAGES-alsa-utils.csv
# Exploring  rosetta-noble/ka
# Exploring  rosetta-noble/ka/LC_MESSAGES
# Created/Updated : ubuntu_by_language\ka\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\de\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\gl\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\el\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\he\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\hu\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\is\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\id\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\it\LC_MESSAGES-alsa-utils.csv
# Exploring  rosetta-noble/jv
# Exploring  rosetta-noble/jv/LC_MESSAGES
# Created/Updated : ubuntu_by_language\jv\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\ja\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\km\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\ko\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\ku\LC_MESSAGES-alsa-utils.csv
# ubuntu_by_language\lo\LC_MESSAGES-alsa-utils.csv is empty.
# Created/Updated : ubuntu_by_language\lv\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\lt\LC_MESSAGES-alsa-utils.csv
# Exploring  rosetta-noble/mk
# Exploring  rosetta-noble/mk/LC_MESSAGES
# ubuntu_by_language\mk\LC_MESSAGES-alsa-utils.csv is empty.
# Created/Updated : ubuntu_by_language\ms\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\nb\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\oc\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\pl\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\pt\LC_MESSAGES-alsa-utils.csv
# ubuntu_by_language\ps\LC_MESSAGES-alsa-utils.csv is empty.
# Created/Updated : ubuntu_by_language\ro\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\ru\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\sr\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\hr\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\sk\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\sl\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\es\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\sv\LC_MESSAGES-alsa-utils.csv
# ubuntu_by_language\ta\LC_MESSAGES-alsa-utils.csv is empty.
# ubuntu_by_language\tg\LC_MESSAGES-alsa-utils.csv is empty.
# Created/Updated : ubuntu_by_language\th\LC_MESSAGES-alsa-utils.csv
# ubuntu_by_language\bo\LC_MESSAGES-alsa-utils.csv is empty.
# Created/Updated : ubuntu_by_language\tr\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\ug\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\uk\LC_MESSAGES-alsa-utils.csv
# ubuntu_by_language\ur\LC_MESSAGES-alsa-utils.csv is empty.
# Created/Updated : ubuntu_by_language\vi\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\pt_BR\LC_MESSAGES-alsa-utils.csv
# Exploring  rosetta-noble/pt_PT
# Exploring  rosetta-noble/pt_PT/LC_MESSAGES
# Created/Updated : ubuntu_by_language\pt_PT\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\en_GB\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\en_AU\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\zh_TW\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\zh_CN\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\en_CA\LC_MESSAGES-alsa-utils.csv
# Created/Updated : ubuntu_by_language\af\LC_MESSAGES-apt.csv
# Created/Updated : ubuntu_by_language\sq\LC_MESSAGES-apt.csv
# Created/Updated : ubuntu_by_language\am\LC_MESSAGES-apt.csv
# Created/Updated : ubuntu_by_language\ar\LC_MESSAGES-apt.csv
# Exploring  rosetta-noble/arn
# Exploring  rosetta-noble/arn/LC_MESSAGES
# Created/Updated : ubuntu_by_language\arn\LC_MESSAGES-apt.csv
# Created/Updated : ubuntu_by_language\ast\LC_MESSAGES-apt.csv
# Exploring  rosetta-noble/az
# Exploring  rosetta-noble/az/LC_MESSAGES
# Created/Updated : ubuntu_by_language\az\LC_MESSAGES-apt.csv
# Created/Updated : ubuntu_by_language\eu\LC_MESSAGES-apt.csv
# Created/Updated : ubuntu_by_language\be\LC_MESSAGES-apt.csv
# Created/Updated : ubuntu_by_language\bn\LC_MESSAGES-apt.csv
# Created/Updated : ubuntu_by_language\bs\LC_MESSAGES-apt.csv
# Created/Updated : ubuntu_by_language\br\LC_MESSAGES-apt.csv
# Created/Updated : ubuntu_by_language\bg\LC_MESSAGES-apt.csv
# Created/Updated : ubuntu_by_language\my\LC_MESSAGES-apt.csv
# Created/Updated : ubuntu_by_language\ca\LC_MESSAGES-apt.csv
# Created/Updated : ubuntu_by_language\cs\LC_MESSAGES-apt.csv
# Created/Updated : ubuntu_by_language\da\LC_MESSAGES-apt.csv
# Created/Updated : ubuntu_by_language\nl\LC_MESSAGES-apt.csv
# Exploring  rosetta-noble/dz
# Exploring  rosetta-noble/dz/LC_MESSAGES
# Created/Updated : ubuntu_by_language\dz\LC_MESSAGES-apt.csv
# Created/Updated : ubuntu_by_language\eo\LC_MESSAGES-apt.csv
# Created/Updated : ubuntu_by_language\et\LC_MESSAGES-apt.csv
# Created/Updated : ubuntu_by_language\fi\LC_MESSAGES-apt.csv
# Created/Updated : ubuntu_by_language\fr\LC_MESSAGES-apt.csv
# Created/Updated : ubuntu_by_language\ka\LC_MESSAGES-apt.csv
# Created/Updated : ubuntu_by_language\de\LC_MESSAGES-apt.csv
# Exploring  rosetta-noble/ga
# Exploring  rosetta-noble/ga/LC_MESSAGES
# Created/Updated : ubuntu_by_language\ga\LC_MESSAGES-apt.csv
# Created/Updated : ubuntu_by_language\gl\LC_MESSAGES-apt.csv
# Created/Updated : ubuntu_by_language\el\LC_MESSAGES-apt.csv
# Created/Updated : ubuntu_by_language\he\LC_MESSAGES-apt.csv
# Created/Updated : ubuntu_by_language\hi\LC_MESSAGES-apt.csv
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# File c:\Users\Romain Darous\AppData\Local\Programs\Python\Python312\Lib\pathlib.py:1311, in Path.mkdir(self, mode, parents, exist_ok)
#    1310 try:
# -> 1311     os.mkdir(self, mode)
#    1312 except FileNotFoundError:
#
# FileExistsError: [WinError 183] Impossible de créer un fichier déjà existant: 'ubuntu_by_language\\hu'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 collector.get_ubuntu_translation("https://translations.launchpad.net/ubuntu/noble/+translations")
#
# File g:\Mon Drive\Master_Thesis_Canonical\0_project_pipeline\1_data_collection\collector.py:302, in Collector.get_ubuntu_translation(self, url)
#     299             if f is None : continue
#     301             content = f.read()
# --> 302             updated = self.po_to_csv(content.decode('utf-8').split('\n'), tmp_path)
#     303             if updated : total_added_updated.append(str(tmp_path) + '\n')
#     305 # Saving all updated/created files
#
# File g:\Mon Drive\Master_Thesis_Canonical\0_project_pipeline\1_data_collection\collector.py:373, in Collector.po_to_csv(self, po_content, csv_path)
#     371 dataframe['last-update'] = None
#     372 dataframe.at[0, 'last-update'] = new_date
# --> 373 csv_path.parent.mkdir(parents=True, exist_ok=True)
#     374 dataframe.to_csv(csv_path, encoding='utf-8', index=False)
#     375 print(f'Created/Updated : {csv_path}')
#
# File c:\Users\Romain Darous\AppData\Local\Programs\Python\Python312\Lib\pathlib.py:1320, in Path.mkdir(self, mode, parents, exist_ok)
#    1316     self.mkdir(mode, parents=False, exist_ok=exist_ok)
#    1317 except OSError:
#    1318     # Cannot rely on checking for EEXIST, since the operating system
#    1319     # could give priority to other errors like EACCES or EROFS
# -> 1320     if not exist_ok or not self.is_dir():
#    1321         raise
#
# File c:\Users\Romain Darous\AppData\Local\Programs\Python\Python312\Lib\pathlib.py:875, in Path.is_dir(self)
#     871 """
#     872 Whether this path is a directory.
#     873 """
#     874 try:
# --> 875     return S_ISDIR(self.stat().st_mode)
#     876 except OSError as e:
#     877     if not _ignore_error(e):
#
# File c:\Users\Romain Darous\AppData\Local\Programs\Python\Python312\Lib\pathlib.py:840, in Path.stat(self, follow_symlinks)
#     835 def stat(self, *, follow_symlinks=True):
#     836     """
#     837     Return the result of the stat() system call on this path, like
#     838     os.stat() does.
#     839     """
# --> 840     return os.stat(self, follow_symlinks=follow_symlinks)
#
# KeyboardInterrupt:
