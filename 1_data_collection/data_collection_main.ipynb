# %% [markdown]
# # AI translation validation for Ubuntu - Data collection
#
# Use of Weblate API to automatically collect, store and update desired translations on the website Weblate.

# %% [markdown]
# # Importing annex useful functions

# %%
# Personal libraries
import importlib
import collector
from collector import Collector

# %%
importlib.reload(collector)
from collector import Collector
collector = Collector()

# %% [markdown]
# # Weblate projects
# Given a list of projects (or of keywords contained in the desired project names), one can download all its translations, in all languages using the function ``get_all_translations`` function :

# %%
# list of weblate apis and the associated desired project. when ALL : all the projects will be downloaded
wanted_projects = ["ubuntu", "debian"]

wanted_projects = ["debian handbook"]
collector.get_all_translations("https://hosted.weblate.org/api/", "wlu_F8mRZZeJG9OZ4Y3NfGW6lakufaKJPu7IQFwI", wanted_projects)

# %% [markdown]
# # openSUSE translations
# openSUSE uses its own translation website, but it is also based on the Weblate API. Hence, it is possible to quickly adapt the previous code to collect all the translation of the software, that are numerous.

# %%
# list of weblate apis and the associated desired project. when ALL : all the projects will be downloaded
wanted_projects = ["ALL"]
collector.get_all_translations("https://l10n.opensuse.org/api/", "", wanted_projects)

# %% [markdown]
# # Ubuntu Launchpad translations
# Ubuntu translations are available on Launchpad, that allows to download a .zip file with all translations. We will use this way to download them, and we will save the update time in case an update is required. <br>
# **Note :** the dataset could be extended with previous versions of Ubuntu, that are also available on Launchpad.

# %%
collector.get_ubuntu_translation("https://translations.launchpad.net/ubuntu/noble/+translations")
# Out:
# Archive name: ubuntu-noble-translations.tar.gz
# ubuntu-noble-translations.tar.gz already downloaded.
# CAUTION : ASSUMING IT'S THE LAST VERSION OF THE ARCHIVE
# Exploring  rosetta-noble
# Exploring  rosetta-noble/af
# Exploring  rosetta-noble/af/LC_MESSAGES
# Created/Updated : os_by_language\dataset\af\LC_MESSAGES-adduser-af.csv
# Exploring  rosetta-noble/sq
# Exploring  rosetta-noble/sq/LC_MESSAGES
# Created/Updated : os_by_language\dataset\sq\LC_MESSAGES-adduser-sq.csv
# Exploring  rosetta-noble/am
# Exploring  rosetta-noble/am/LC_MESSAGES
# Created/Updated : os_by_language\dataset\am\LC_MESSAGES-adduser-am.csv
# Exploring  rosetta-noble/ar
# Exploring  rosetta-noble/ar/LC_MESSAGES
# os_by_language\dataset\ar\LC_MESSAGES-adduser-ar.csv is empty.
# Exploring  rosetta-noble/an
# Exploring  rosetta-noble/an/LC_MESSAGES
# os_by_language\dataset\an\LC_MESSAGES-adduser-an.csv is empty.
# Exploring  rosetta-noble/ast
# Exploring  rosetta-noble/ast/LC_MESSAGES
# Created/Updated : os_by_language\dataset\ast\LC_MESSAGES-adduser-ast.csv
# Exploring  rosetta-noble/eu
# Exploring  rosetta-noble/eu/LC_MESSAGES
# Created/Updated : os_by_language\dataset\eu\LC_MESSAGES-adduser-eu.csv
# Exploring  rosetta-noble/be
# Exploring  rosetta-noble/be/LC_MESSAGES
# Created/Updated : os_by_language\dataset\be\LC_MESSAGES-adduser-be.csv
# Exploring  rosetta-noble/bn
# Exploring  rosetta-noble/bn/LC_MESSAGES
# Created/Updated : os_by_language\dataset\bn\LC_MESSAGES-adduser-bn.csv
# Exploring  rosetta-noble/bs
# Exploring  rosetta-noble/bs/LC_MESSAGES
# Created/Updated : os_by_language\dataset\bs\LC_MESSAGES-adduser-bs.csv
# Exploring  rosetta-noble/bg
# Exploring  rosetta-noble/bg/LC_MESSAGES
# Created/Updated : os_by_language\dataset\bg\LC_MESSAGES-adduser-bg.csv
# Exploring  rosetta-noble/my
# Exploring  rosetta-noble/my/LC_MESSAGES
# Created/Updated : os_by_language\dataset\my\LC_MESSAGES-adduser-my.csv
# Exploring  rosetta-noble/ca
# Exploring  rosetta-noble/ca/LC_MESSAGES
# Created/Updated : os_by_language\dataset\ca\LC_MESSAGES-adduser-ca.csv
# Exploring  rosetta-noble/ce
# Exploring  rosetta-noble/ce/LC_MESSAGES
# os_by_language\dataset\ce\LC_MESSAGES-adduser-ce.csv is empty.
# Exploring  rosetta-noble/cs
# Exploring  rosetta-noble/cs/LC_MESSAGES
# Created/Updated : os_by_language\dataset\cs\LC_MESSAGES-adduser-cs.csv
# Exploring  rosetta-noble/da
# Exploring  rosetta-noble/da/LC_MESSAGES
# Created/Updated : os_by_language\dataset\da\LC_MESSAGES-adduser-da.csv
# Exploring  rosetta-noble/dsb
# Exploring  rosetta-noble/dsb/LC_MESSAGES
# Created/Updated : os_by_language\dataset\dsb\LC_MESSAGES-adduser-dsb.csv
# Exploring  rosetta-noble/nl
# Exploring  rosetta-noble/nl/LC_MESSAGES
# Created/Updated : os_by_language\dataset\nl\LC_MESSAGES-adduser-nl.csv
# Exploring  rosetta-noble/en
# Exploring  rosetta-noble/en/LC_MESSAGES
# os_by_language\dataset\en\LC_MESSAGES-adduser-en.csv is empty.
# Exploring  rosetta-noble/eo
# Exploring  rosetta-noble/eo/LC_MESSAGES
# Created/Updated : os_by_language\dataset\eo\LC_MESSAGES-adduser-eo.csv
# Exploring  rosetta-noble/et
# Exploring  rosetta-noble/et/LC_MESSAGES
# Created/Updated : os_by_language\dataset\et\LC_MESSAGES-adduser-et.csv
# Exploring  rosetta-noble/fi
# Exploring  rosetta-noble/fi/LC_MESSAGES
# Created/Updated : os_by_language\dataset\fi\LC_MESSAGES-adduser-fi.csv
# Exploring  rosetta-noble/fr
# Exploring  rosetta-noble/fr/LC_MESSAGES
# Created/Updated : os_by_language\dataset\fr\LC_MESSAGES-adduser-fr.csv
# Exploring  rosetta-noble/de
# Exploring  rosetta-noble/de/LC_MESSAGES
# Created/Updated : os_by_language\dataset\de\LC_MESSAGES-adduser-de.csv
# Exploring  rosetta-noble/gl
# Exploring  rosetta-noble/gl/LC_MESSAGES
# Created/Updated : os_by_language\dataset\gl\LC_MESSAGES-adduser-gl.csv
# Exploring  rosetta-noble/el
# Exploring  rosetta-noble/el/LC_MESSAGES
# Created/Updated : os_by_language\dataset\el\LC_MESSAGES-adduser-el.csv
# Exploring  rosetta-noble/gu
# Exploring  rosetta-noble/gu/LC_MESSAGES
# Created/Updated : os_by_language\dataset\gu\LC_MESSAGES-adduser-gu.csv
# Exploring  rosetta-noble/he
# Exploring  rosetta-noble/he/LC_MESSAGES
# Created/Updated : os_by_language\dataset\he\LC_MESSAGES-adduser-he.csv
# Exploring  rosetta-noble/hi
# Exploring  rosetta-noble/hi/LC_MESSAGES
# Created/Updated : os_by_language\dataset\hi\LC_MESSAGES-adduser-hi.csv
# Exploring  rosetta-noble/hu
# Exploring  rosetta-noble/hu/LC_MESSAGES
# Created/Updated : os_by_language\dataset\hu\LC_MESSAGES-adduser-hu.csv
# Exploring  rosetta-noble/is
# Exploring  rosetta-noble/is/LC_MESSAGES
# Created/Updated : os_by_language\dataset\is\LC_MESSAGES-adduser-is.csv
# Exploring  rosetta-noble/id
# Exploring  rosetta-noble/id/LC_MESSAGES
# Created/Updated : os_by_language\dataset\id\LC_MESSAGES-adduser-id.csv
# Exploring  rosetta-noble/it
# Exploring  rosetta-noble/it/LC_MESSAGES
# Created/Updated : os_by_language\dataset\it\LC_MESSAGES-adduser-it.csv
# Exploring  rosetta-noble/ja
# Exploring  rosetta-noble/ja/LC_MESSAGES
# Created/Updated : os_by_language\dataset\ja\LC_MESSAGES-adduser-ja.csv
# Exploring  rosetta-noble/kl
# Exploring  rosetta-noble/kl/LC_MESSAGES
# os_by_language\dataset\kl\LC_MESSAGES-adduser-kl.csv is empty.
# Exploring  rosetta-noble/kn
# Exploring  rosetta-noble/kn/LC_MESSAGES
# Created/Updated : os_by_language\dataset\kn\LC_MESSAGES-adduser-kn.csv
# Exploring  rosetta-noble/km
# Exploring  rosetta-noble/km/LC_MESSAGES
# os_by_language\dataset\km\LC_MESSAGES-adduser-km.csv is empty.
# Exploring  rosetta-noble/ko
# Exploring  rosetta-noble/ko/LC_MESSAGES
# Created/Updated : os_by_language\dataset\ko\LC_MESSAGES-adduser-ko.csv
# Exploring  rosetta-noble/ku
# Exploring  rosetta-noble/ku/LC_MESSAGES
# Created/Updated : os_by_language\dataset\ku\LC_MESSAGES-adduser-ku.csv
# Exploring  rosetta-noble/lo
# Exploring  rosetta-noble/lo/LC_MESSAGES
# os_by_language\dataset\lo\LC_MESSAGES-adduser-lo.csv is empty.
# Exploring  rosetta-noble/lv
# Exploring  rosetta-noble/lv/LC_MESSAGES
# Created/Updated : os_by_language\dataset\lv\LC_MESSAGES-adduser-lv.csv
# Exploring  rosetta-noble/lt
# Exploring  rosetta-noble/lt/LC_MESSAGES
# Created/Updated : os_by_language\dataset\lt\LC_MESSAGES-adduser-lt.csv
# Exploring  rosetta-noble/ms
# Exploring  rosetta-noble/ms/LC_MESSAGES
# Created/Updated : os_by_language\dataset\ms\LC_MESSAGES-adduser-ms.csv
# Exploring  rosetta-noble/mn
# Exploring  rosetta-noble/mn/LC_MESSAGES
# Created/Updated : os_by_language\dataset\mn\LC_MESSAGES-adduser-mn.csv
# Exploring  rosetta-noble/nds
# Exploring  rosetta-noble/nds/LC_MESSAGES
# os_by_language\dataset\nds\LC_MESSAGES-adduser-nds.csv is empty.
# Exploring  rosetta-noble/nn
# Exploring  rosetta-noble/nn/LC_MESSAGES
# Created/Updated : os_by_language\dataset\nn\LC_MESSAGES-adduser-nn.csv
# Exploring  rosetta-noble/nb
# Exploring  rosetta-noble/nb/LC_MESSAGES
# Created/Updated : os_by_language\dataset\nb\LC_MESSAGES-adduser-nb.csv
# Exploring  rosetta-noble/oc
# Exploring  rosetta-noble/oc/LC_MESSAGES
# Created/Updated : os_by_language\dataset\oc\LC_MESSAGES-adduser-oc.csv
# Exploring  rosetta-noble/om
# Exploring  rosetta-noble/om/LC_MESSAGES
# Created/Updated : os_by_language\dataset\om\LC_MESSAGES-adduser-om.csv
# Exploring  rosetta-noble/fa
# Exploring  rosetta-noble/fa/LC_MESSAGES
# Created/Updated : os_by_language\dataset\fa\LC_MESSAGES-adduser-fa.csv
# Exploring  rosetta-noble/pl
# Exploring  rosetta-noble/pl/LC_MESSAGES
# Created/Updated : os_by_language\dataset\pl\LC_MESSAGES-adduser-pl.csv
# Exploring  rosetta-noble/pt
# Exploring  rosetta-noble/pt/LC_MESSAGES
# Created/Updated : os_by_language\dataset\pt\LC_MESSAGES-adduser-pt.csv
# Exploring  rosetta-noble/ps
# Exploring  rosetta-noble/ps/LC_MESSAGES
# os_by_language\dataset\ps\LC_MESSAGES-adduser-ps.csv is empty.
# Exploring  rosetta-noble/ro
# Exploring  rosetta-noble/ro/LC_MESSAGES
# Created/Updated : os_by_language\dataset\ro\LC_MESSAGES-adduser-ro.csv
# Exploring  rosetta-noble/ru
# Exploring  rosetta-noble/ru/LC_MESSAGES
# Created/Updated : os_by_language\dataset\ru\LC_MESSAGES-adduser-ru.csv
# Exploring  rosetta-noble/sr
# Exploring  rosetta-noble/sr/LC_MESSAGES
# Created/Updated : os_by_language\dataset\sr\LC_MESSAGES-adduser-sr.csv
# Exploring  rosetta-noble/sco
# Exploring  rosetta-noble/sco/LC_MESSAGES
# Created/Updated : os_by_language\dataset\sco\LC_MESSAGES-adduser-sco.csv
# Exploring  rosetta-noble/hr
# Exploring  rosetta-noble/hr/LC_MESSAGES
# Created/Updated : os_by_language\dataset\hr\LC_MESSAGES-adduser-hr.csv
# Exploring  rosetta-noble/sk
# Exploring  rosetta-noble/sk/LC_MESSAGES
# Created/Updated : os_by_language\dataset\sk\LC_MESSAGES-adduser-sk.csv
# Exploring  rosetta-noble/sl
# Exploring  rosetta-noble/sl/LC_MESSAGES
# Created/Updated : os_by_language\dataset\sl\LC_MESSAGES-adduser-sl.csv
# Exploring  rosetta-noble/es
# Exploring  rosetta-noble/es/LC_MESSAGES
# Created/Updated : os_by_language\dataset\es\LC_MESSAGES-adduser-es.csv
# Exploring  rosetta-noble/sv
# Exploring  rosetta-noble/sv/LC_MESSAGES
# Created/Updated : os_by_language\dataset\sv\LC_MESSAGES-adduser-sv.csv
# Exploring  rosetta-noble/ta
# Exploring  rosetta-noble/ta/LC_MESSAGES
# os_by_language\dataset\ta\LC_MESSAGES-adduser-ta.csv is empty.
# Exploring  rosetta-noble/te
# Exploring  rosetta-noble/te/LC_MESSAGES
# Created/Updated : os_by_language\dataset\te\LC_MESSAGES-adduser-te.csv
# Exploring  rosetta-noble/tg
# Exploring  rosetta-noble/tg/LC_MESSAGES
# os_by_language\dataset\tg\LC_MESSAGES-adduser-tg.csv is empty.
# Exploring  rosetta-noble/tl
# Exploring  rosetta-noble/tl/LC_MESSAGES
# os_by_language\dataset\tl\LC_MESSAGES-adduser-tl.csv is empty.
# Exploring  rosetta-noble/th
# Exploring  rosetta-noble/th/LC_MESSAGES
# Created/Updated : os_by_language\dataset\th\LC_MESSAGES-adduser-th.csv
# Exploring  rosetta-noble/bo
# Exploring  rosetta-noble/bo/LC_MESSAGES
# os_by_language\dataset\bo\LC_MESSAGES-adduser-bo.csv is empty.
# Exploring  rosetta-noble/tr
# Exploring  rosetta-noble/tr/LC_MESSAGES
# Created/Updated : os_by_language\dataset\tr\LC_MESSAGES-adduser-tr.csv
# Exploring  rosetta-noble/ug
# Exploring  rosetta-noble/ug/LC_MESSAGES
# Created/Updated : os_by_language\dataset\ug\LC_MESSAGES-adduser-ug.csv
# Exploring  rosetta-noble/uk
# Exploring  rosetta-noble/uk/LC_MESSAGES
# Created/Updated : os_by_language\dataset\uk\LC_MESSAGES-adduser-uk.csv
# Exploring  rosetta-noble/ur
# Exploring  rosetta-noble/ur/LC_MESSAGES
# Created/Updated : os_by_language\dataset\ur\LC_MESSAGES-adduser-ur.csv
# Exploring  rosetta-noble/vi
# Exploring  rosetta-noble/vi/LC_MESSAGES
# Created/Updated : os_by_language\dataset\vi\LC_MESSAGES-adduser-vi.csv
# Exploring  rosetta-noble/zh_HK
# Exploring  rosetta-noble/zh_HK/LC_MESSAGES
# Created/Updated : os_by_language\dataset\zh_HK\LC_MESSAGES-adduser-zh_HK.csv
# Exploring  rosetta-noble/en_US
# Exploring  rosetta-noble/en_US/LC_MESSAGES
# os_by_language\dataset\en_US\LC_MESSAGES-adduser-en_US.csv is empty.
# Exploring  rosetta-noble/pt_BR
# Exploring  rosetta-noble/pt_BR/LC_MESSAGES
# Created/Updated : os_by_language\dataset\pt_BR\LC_MESSAGES-adduser-pt_BR.csv
# Exploring  rosetta-noble/en_GB
# Exploring  rosetta-noble/en_GB/LC_MESSAGES
# Created/Updated : os_by_language\dataset\en_GB\LC_MESSAGES-adduser-en_GB.csv
# Exploring  rosetta-noble/fr_CA
# Exploring  rosetta-noble/fr_CA/LC_MESSAGES
# os_by_language\dataset\fr_CA\LC_MESSAGES-adduser-fr_CA.csv is empty.
# Exploring  rosetta-noble/en_AU
# Exploring  rosetta-noble/en_AU/LC_MESSAGES
# Created/Updated : os_by_language\dataset\en_AU\LC_MESSAGES-adduser-en_AU.csv
# Exploring  rosetta-noble/zh_TW
# Exploring  rosetta-noble/zh_TW/LC_MESSAGES
# Created/Updated : os_by_language\dataset\zh_TW\LC_MESSAGES-adduser-zh_TW.csv
# Exploring  rosetta-noble/zh_CN
# Exploring  rosetta-noble/zh_CN/LC_MESSAGES
# Created/Updated : os_by_language\dataset\zh_CN\LC_MESSAGES-adduser-zh_CN.csv
# Exploring  rosetta-noble/es_ES
# Exploring  rosetta-noble/es_ES/LC_MESSAGES
# os_by_language\dataset\es_ES\LC_MESSAGES-adduser-es_ES.csv is empty.
# Exploring  rosetta-noble/de_DE
# Exploring  rosetta-noble/de_DE/LC_MESSAGES
# Created/Updated : os_by_language\dataset\de_DE\LC_MESSAGES-adduser-de_DE.csv
# Exploring  rosetta-noble/en_CA
# Exploring  rosetta-noble/en_CA/LC_MESSAGES
# Created/Updated : os_by_language\dataset\en_CA\LC_MESSAGES-adduser-en_CA.csv
# Exploring  rosetta-noble/miq
# Exploring  rosetta-noble/miq/LC_MESSAGES
# os_by_language\dataset\miq\LC_MESSAGES-adduser-miq.csv is empty.
# Exploring  rosetta-noble/ta_LK
# Exploring  rosetta-noble/ta_LK/LC_MESSAGES
# os_by_language\dataset\ta_LK\LC_MESSAGES-adduser-ta_LK.csv is empty.
# Created/Updated : os_by_language\dataset\af\LC_MESSAGES-alsa-utils-af.csv
# Created/Updated : os_by_language\dataset\sq\LC_MESSAGES-alsa-utils-sq.csv
# Created/Updated : os_by_language\dataset\ar\LC_MESSAGES-alsa-utils-ar.csv
# Created/Updated : os_by_language\dataset\ast\LC_MESSAGES-alsa-utils-ast.csv
# Created/Updated : os_by_language\dataset\eu\LC_MESSAGES-alsa-utils-eu.csv
# Created/Updated : os_by_language\dataset\be\LC_MESSAGES-alsa-utils-be.csv
# Created/Updated : os_by_language\dataset\bn\LC_MESSAGES-alsa-utils-bn.csv
# Created/Updated : os_by_language\dataset\bs\LC_MESSAGES-alsa-utils-bs.csv
# Exploring  rosetta-noble/br
# Exploring  rosetta-noble/br/LC_MESSAGES
# Created/Updated : os_by_language\dataset\br\LC_MESSAGES-alsa-utils-br.csv
# Created/Updated : os_by_language\dataset\bg\LC_MESSAGES-alsa-utils-bg.csv
# Created/Updated : os_by_language\dataset\ca\LC_MESSAGES-alsa-utils-ca.csv
# os_by_language\dataset\ce\LC_MESSAGES-alsa-utils-ce.csv is empty.
# Created/Updated : os_by_language\dataset\cs\LC_MESSAGES-alsa-utils-cs.csv
# Created/Updated : os_by_language\dataset\da\LC_MESSAGES-alsa-utils-da.csv
# Created/Updated : os_by_language\dataset\nl\LC_MESSAGES-alsa-utils-nl.csv
# Created/Updated : os_by_language\dataset\fi\LC_MESSAGES-alsa-utils-fi.csv
# Created/Updated : os_by_language\dataset\fr\LC_MESSAGES-alsa-utils-fr.csv
# Exploring  rosetta-noble/ka
# Exploring  rosetta-noble/ka/LC_MESSAGES
# Created/Updated : os_by_language\dataset\ka\LC_MESSAGES-alsa-utils-ka.csv
# Created/Updated : os_by_language\dataset\de\LC_MESSAGES-alsa-utils-de.csv
# Created/Updated : os_by_language\dataset\gl\LC_MESSAGES-alsa-utils-gl.csv
# Created/Updated : os_by_language\dataset\el\LC_MESSAGES-alsa-utils-el.csv
# Created/Updated : os_by_language\dataset\he\LC_MESSAGES-alsa-utils-he.csv
# Created/Updated : os_by_language\dataset\hu\LC_MESSAGES-alsa-utils-hu.csv
# Created/Updated : os_by_language\dataset\is\LC_MESSAGES-alsa-utils-is.csv
# Created/Updated : os_by_language\dataset\id\LC_MESSAGES-alsa-utils-id.csv
# Created/Updated : os_by_language\dataset\it\LC_MESSAGES-alsa-utils-it.csv
# Exploring  rosetta-noble/jv
# Exploring  rosetta-noble/jv/LC_MESSAGES
# Created/Updated : os_by_language\dataset\jv\LC_MESSAGES-alsa-utils-jv.csv
# Created/Updated : os_by_language\dataset\ja\LC_MESSAGES-alsa-utils-ja.csv
# Created/Updated : os_by_language\dataset\km\LC_MESSAGES-alsa-utils-km.csv
# Created/Updated : os_by_language\dataset\ko\LC_MESSAGES-alsa-utils-ko.csv
# Created/Updated : os_by_language\dataset\ku\LC_MESSAGES-alsa-utils-ku.csv
# os_by_language\dataset\lo\LC_MESSAGES-alsa-utils-lo.csv is empty.
# Created/Updated : os_by_language\dataset\lv\LC_MESSAGES-alsa-utils-lv.csv
# Created/Updated : os_by_language\dataset\lt\LC_MESSAGES-alsa-utils-lt.csv
# Exploring  rosetta-noble/mk
# Exploring  rosetta-noble/mk/LC_MESSAGES
# os_by_language\dataset\mk\LC_MESSAGES-alsa-utils-mk.csv is empty.
# Created/Updated : os_by_language\dataset\ms\LC_MESSAGES-alsa-utils-ms.csv
# Created/Updated : os_by_language\dataset\nb\LC_MESSAGES-alsa-utils-nb.csv
# Created/Updated : os_by_language\dataset\oc\LC_MESSAGES-alsa-utils-oc.csv
# Created/Updated : os_by_language\dataset\pl\LC_MESSAGES-alsa-utils-pl.csv
# Created/Updated : os_by_language\dataset\pt\LC_MESSAGES-alsa-utils-pt.csv
# os_by_language\dataset\ps\LC_MESSAGES-alsa-utils-ps.csv is empty.
# Created/Updated : os_by_language\dataset\ro\LC_MESSAGES-alsa-utils-ro.csv
# Created/Updated : os_by_language\dataset\ru\LC_MESSAGES-alsa-utils-ru.csv
# Created/Updated : os_by_language\dataset\sr\LC_MESSAGES-alsa-utils-sr.csv
# Created/Updated : os_by_language\dataset\hr\LC_MESSAGES-alsa-utils-hr.csv
# Created/Updated : os_by_language\dataset\sk\LC_MESSAGES-alsa-utils-sk.csv
# Created/Updated : os_by_language\dataset\sl\LC_MESSAGES-alsa-utils-sl.csv
# Created/Updated : os_by_language\dataset\es\LC_MESSAGES-alsa-utils-es.csv
# Created/Updated : os_by_language\dataset\sv\LC_MESSAGES-alsa-utils-sv.csv
# os_by_language\dataset\ta\LC_MESSAGES-alsa-utils-ta.csv is empty.
# os_by_language\dataset\tg\LC_MESSAGES-alsa-utils-tg.csv is empty.
# Created/Updated : os_by_language\dataset\th\LC_MESSAGES-alsa-utils-th.csv
# os_by_language\dataset\bo\LC_MESSAGES-alsa-utils-bo.csv is empty.
# Created/Updated : os_by_language\dataset\tr\LC_MESSAGES-alsa-utils-tr.csv
# Created/Updated : os_by_language\dataset\ug\LC_MESSAGES-alsa-utils-ug.csv
# Created/Updated : os_by_language\dataset\uk\LC_MESSAGES-alsa-utils-uk.csv
# os_by_language\dataset\ur\LC_MESSAGES-alsa-utils-ur.csv is empty.
# Created/Updated : os_by_language\dataset\vi\LC_MESSAGES-alsa-utils-vi.csv
# Created/Updated : os_by_language\dataset\pt_BR\LC_MESSAGES-alsa-utils-pt_BR.csv
# Exploring  rosetta-noble/pt_PT
# Exploring  rosetta-noble/pt_PT/LC_MESSAGES
# Created/Updated : os_by_language\dataset\pt_PT\LC_MESSAGES-alsa-utils-pt_PT.csv
# Created/Updated : os_by_language\dataset\en_GB\LC_MESSAGES-alsa-utils-en_GB.csv
# Created/Updated : os_by_language\dataset\en_AU\LC_MESSAGES-alsa-utils-en_AU.csv
# Created/Updated : os_by_language\dataset\zh_TW\LC_MESSAGES-alsa-utils-zh_TW.csv
# Created/Updated : os_by_language\dataset\zh_CN\LC_MESSAGES-alsa-utils-zh_CN.csv
# Created/Updated : os_by_language\dataset\en_CA\LC_MESSAGES-alsa-utils-en_CA.csv
# Created/Updated : os_by_language\dataset\af\LC_MESSAGES-apt-af.csv
# Created/Updated : os_by_language\dataset\sq\LC_MESSAGES-apt-sq.csv
# Created/Updated : os_by_language\dataset\am\LC_MESSAGES-apt-am.csv
# Created/Updated : os_by_language\dataset\ar\LC_MESSAGES-apt-ar.csv
# Exploring  rosetta-noble/arn
# Exploring  rosetta-noble/arn/LC_MESSAGES
# Created/Updated : os_by_language\dataset\arn\LC_MESSAGES-apt-arn.csv
# Created/Updated : os_by_language\dataset\ast\LC_MESSAGES-apt-ast.csv
# Exploring  rosetta-noble/az
# Exploring  rosetta-noble/az/LC_MESSAGES
# Created/Updated : os_by_language\dataset\az\LC_MESSAGES-apt-az.csv
# Created/Updated : os_by_language\dataset\eu\LC_MESSAGES-apt-eu.csv
# Created/Updated : os_by_language\dataset\be\LC_MESSAGES-apt-be.csv
# Created/Updated : os_by_language\dataset\bn\LC_MESSAGES-apt-bn.csv
# Created/Updated : os_by_language\dataset\bs\LC_MESSAGES-apt-bs.csv
# Created/Updated : os_by_language\dataset\br\LC_MESSAGES-apt-br.csv
# Created/Updated : os_by_language\dataset\bg\LC_MESSAGES-apt-bg.csv
# Created/Updated : os_by_language\dataset\my\LC_MESSAGES-apt-my.csv
# Created/Updated : os_by_language\dataset\ca\LC_MESSAGES-apt-ca.csv
# Created/Updated : os_by_language\dataset\cs\LC_MESSAGES-apt-cs.csv
# Created/Updated : os_by_language\dataset\da\LC_MESSAGES-apt-da.csv
# Created/Updated : os_by_language\dataset\nl\LC_MESSAGES-apt-nl.csv
# Exploring  rosetta-noble/dz
# Exploring  rosetta-noble/dz/LC_MESSAGES
# Created/Updated : os_by_language\dataset\dz\LC_MESSAGES-apt-dz.csv
# Created/Updated : os_by_language\dataset\eo\LC_MESSAGES-apt-eo.csv
# Created/Updated : os_by_language\dataset\et\LC_MESSAGES-apt-et.csv
# Created/Updated : os_by_language\dataset\fi\LC_MESSAGES-apt-fi.csv
# Created/Updated : os_by_language\dataset\fr\LC_MESSAGES-apt-fr.csv
# Created/Updated : os_by_language\dataset\ka\LC_MESSAGES-apt-ka.csv
# Created/Updated : os_by_language\dataset\de\LC_MESSAGES-apt-de.csv
# Exploring  rosetta-noble/ga
# Exploring  rosetta-noble/ga/LC_MESSAGES
# Created/Updated : os_by_language\dataset\ga\LC_MESSAGES-apt-ga.csv
# Created/Updated : os_by_language\dataset\gl\LC_MESSAGES-apt-gl.csv
# Created/Updated : os_by_language\dataset\el\LC_MESSAGES-apt-el.csv
# Created/Updated : os_by_language\dataset\he\LC_MESSAGES-apt-he.csv
# Created/Updated : os_by_language\dataset\hi\LC_MESSAGES-apt-hi.csv
# Created/Updated : os_by_language\dataset\hu\LC_MESSAGES-apt-hu.csv
# Created/Updated : os_by_language\dataset\is\LC_MESSAGES-apt-is.csv
# Exploring  rosetta-noble/ia
# Exploring  rosetta-noble/ia/LC_MESSAGES
# Created/Updated : os_by_language\dataset\ia\LC_MESSAGES-apt-ia.csv
# Created/Updated : os_by_language\dataset\id\LC_MESSAGES-apt-id.csv
# Created/Updated : os_by_language\dataset\it\LC_MESSAGES-apt-it.csv
# Created/Updated : os_by_language\dataset\jv\LC_MESSAGES-apt-jv.csv
# Created/Updated : os_by_language\dataset\ja\LC_MESSAGES-apt-ja.csv
# Exploring  rosetta-noble/kab
# Exploring  rosetta-noble/kab/LC_MESSAGES
# Created/Updated : os_by_language\dataset\kab\LC_MESSAGES-apt-kab.csv
# Created/Updated : os_by_language\dataset\km\LC_MESSAGES-apt-km.csv
# Created/Updated : os_by_language\dataset\ko\LC_MESSAGES-apt-ko.csv
# Created/Updated : os_by_language\dataset\ku\LC_MESSAGES-apt-ku.csv
# Created/Updated : os_by_language\dataset\lo\LC_MESSAGES-apt-lo.csv
# Created/Updated : os_by_language\dataset\lv\LC_MESSAGES-apt-lv.csv
# Created/Updated : os_by_language\dataset\lt\LC_MESSAGES-apt-lt.csv
# Created/Updated : os_by_language\dataset\mk\LC_MESSAGES-apt-mk.csv
# Exploring  rosetta-noble/ml
# Exploring  rosetta-noble/ml/LC_MESSAGES
# Created/Updated : os_by_language\dataset\ml\LC_MESSAGES-apt-ml.csv
# Exploring  rosetta-noble/mr
# Exploring  rosetta-noble/mr/LC_MESSAGES
# Created/Updated : os_by_language\dataset\mr\LC_MESSAGES-apt-mr.csv
# Created/Updated : os_by_language\dataset\ms\LC_MESSAGES-apt-ms.csv
# Created/Updated : os_by_language\dataset\mn\LC_MESSAGES-apt-mn.csv
# Created/Updated : os_by_language\dataset\nds\LC_MESSAGES-apt-nds.csv
# Exploring  rosetta-noble/ne
# Exploring  rosetta-noble/ne/LC_MESSAGES
# Created/Updated : os_by_language\dataset\ne\LC_MESSAGES-apt-ne.csv
# Created/Updated : os_by_language\dataset\nn\LC_MESSAGES-apt-nn.csv
# Created/Updated : os_by_language\dataset\nb\LC_MESSAGES-apt-nb.csv
# Created/Updated : os_by_language\dataset\oc\LC_MESSAGES-apt-oc.csv
# Created/Updated : os_by_language\dataset\fa\LC_MESSAGES-apt-fa.csv
# Created/Updated : os_by_language\dataset\pl\LC_MESSAGES-apt-pl.csv
# Created/Updated : os_by_language\dataset\pt\LC_MESSAGES-apt-pt.csv
# Created/Updated : os_by_language\dataset\ps\LC_MESSAGES-apt-ps.csv
# Created/Updated : os_by_language\dataset\ro\LC_MESSAGES-apt-ro.csv
# Created/Updated : os_by_language\dataset\ru\LC_MESSAGES-apt-ru.csv
# Created/Updated : os_by_language\dataset\sr\LC_MESSAGES-apt-sr.csv
# Created/Updated : os_by_language\dataset\hr\LC_MESSAGES-apt-hr.csv
# Created/Updated : os_by_language\dataset\sk\LC_MESSAGES-apt-sk.csv
# Created/Updated : os_by_language\dataset\sl\LC_MESSAGES-apt-sl.csv
# Exploring  rosetta-noble/se
# Exploring  rosetta-noble/se/LC_MESSAGES
# Created/Updated : os_by_language\dataset\se\LC_MESSAGES-apt-se.csv
# Created/Updated : os_by_language\dataset\es\LC_MESSAGES-apt-es.csv
# Created/Updated : os_by_language\dataset\sv\LC_MESSAGES-apt-sv.csv
# Created/Updated : os_by_language\dataset\ta\LC_MESSAGES-apt-ta.csv
# Exploring  rosetta-noble/ts
# Exploring  rosetta-noble/ts/LC_MESSAGES
# Created/Updated : os_by_language\dataset\ts\LC_MESSAGES-apt-ts.csv
# Created/Updated : os_by_language\dataset\tg\LC_MESSAGES-apt-tg.csv
# Created/Updated : os_by_language\dataset\tl\LC_MESSAGES-apt-tl.csv
# Created/Updated : os_by_language\dataset\th\LC_MESSAGES-apt-th.csv
# Created/Updated : os_by_language\dataset\bo\LC_MESSAGES-apt-bo.csv
# Created/Updated : os_by_language\dataset\tr\LC_MESSAGES-apt-tr.csv
# Created/Updated : os_by_language\dataset\ug\LC_MESSAGES-apt-ug.csv
# Created/Updated : os_by_language\dataset\uk\LC_MESSAGES-apt-uk.csv
# Created/Updated : os_by_language\dataset\ur\LC_MESSAGES-apt-ur.csv
# Exploring  rosetta-noble/uz
# Exploring  rosetta-noble/uz/LC_MESSAGES
# Created/Updated : os_by_language\dataset\uz\LC_MESSAGES-apt-uz.csv
# Created/Updated : os_by_language\dataset\vi\LC_MESSAGES-apt-vi.csv
# Exploring  rosetta-noble/cy
# Exploring  rosetta-noble/cy/LC_MESSAGES
# Created/Updated : os_by_language\dataset\cy\LC_MESSAGES-apt-cy.csv
# Created/Updated : os_by_language\dataset\zh_HK\LC_MESSAGES-apt-zh_HK.csv
# Created/Updated : os_by_language\dataset\pt_BR\LC_MESSAGES-apt-pt_BR.csv
# Created/Updated : os_by_language\dataset\pt_PT\LC_MESSAGES-apt-pt_PT.csv
# Created/Updated : os_by_language\dataset\en_GB\LC_MESSAGES-apt-en_GB.csv
# Created/Updated : os_by_language\dataset\en_AU\LC_MESSAGES-apt-en_AU.csv
# Created/Updated : os_by_language\dataset\zh_TW\LC_MESSAGES-apt-zh_TW.csv
# Exploring  rosetta-noble/fr_FR
# Exploring  rosetta-noble/fr_FR/LC_MESSAGES
# Created/Updated : os_by_language\dataset\fr_FR\LC_MESSAGES-apt-fr_FR.csv
# Created/Updated : os_by_language\dataset\zh_CN\LC_MESSAGES-apt-zh_CN.csv
# Created/Updated : os_by_language\dataset\en_CA\LC_MESSAGES-apt-en_CA.csv
# Exploring  rosetta-noble/fil
# Exploring  rosetta-noble/fil/LC_MESSAGES
# Created/Updated : os_by_language\dataset\fil\LC_MESSAGES-apt-fil.csv
# Exploring  rosetta-noble/ca@valencia
# Exploring  rosetta-noble/ca@valencia/LC_MESSAGES
# Created/Updated : os_by_language\dataset\ca@valencia\LC_MESSAGES-apt-ca@valencia.csv
# Exploring  rosetta-noble/mnw
# Exploring  rosetta-noble/mnw/LC_MESSAGES
# Created/Updated : os_by_language\dataset\mnw\LC_MESSAGES-apt-mnw.csv
# Created/Updated : os_by_language\dataset\af\LC_MESSAGES-apt-utils-af.csv
# Created/Updated : os_by_language\dataset\sq\LC_MESSAGES-apt-utils-sq.csv
# Created/Updated : os_by_language\dataset\ar\LC_MESSAGES-apt-utils-ar.csv
# Created/Updated : os_by_language\dataset\ast\LC_MESSAGES-apt-utils-ast.csv
# Created/Updated : os_by_language\dataset\eu\LC_MESSAGES-apt-utils-eu.csv
# os_by_language\dataset\be\LC_MESSAGES-apt-utils-be.csv is empty.
# Created/Updated : os_by_language\dataset\bs\LC_MESSAGES-apt-utils-bs.csv
# Created/Updated : os_by_language\dataset\bg\LC_MESSAGES-apt-utils-bg.csv
# Created/Updated : os_by_language\dataset\ca\LC_MESSAGES-apt-utils-ca.csv
# os_by_language\dataset\ce\LC_MESSAGES-apt-utils-ce.csv is empty.
# Created/Updated : os_by_language\dataset\cs\LC_MESSAGES-apt-utils-cs.csv
# Created/Updated : os_by_language\dataset\da\LC_MESSAGES-apt-utils-da.csv
# Created/Updated : os_by_language\dataset\nl\LC_MESSAGES-apt-utils-nl.csv
# Created/Updated : os_by_language\dataset\dz\LC_MESSAGES-apt-utils-dz.csv
# Created/Updated : os_by_language\dataset\fi\LC_MESSAGES-apt-utils-fi.csv
# Created/Updated : os_by_language\dataset\fr\LC_MESSAGES-apt-utils-fr.csv
# Created/Updated : os_by_language\dataset\de\LC_MESSAGES-apt-utils-de.csv
# Created/Updated : os_by_language\dataset\gl\LC_MESSAGES-apt-utils-gl.csv
# Created/Updated : os_by_language\dataset\el\LC_MESSAGES-apt-utils-el.csv
# Created/Updated : os_by_language\dataset\hu\LC_MESSAGES-apt-utils-hu.csv
# Created/Updated : os_by_language\dataset\id\LC_MESSAGES-apt-utils-id.csv
# Created/Updated : os_by_language\dataset\it\LC_MESSAGES-apt-utils-it.csv
# Created/Updated : os_by_language\dataset\ja\LC_MESSAGES-apt-utils-ja.csv
# Created/Updated : os_by_language\dataset\km\LC_MESSAGES-apt-utils-km.csv
# Created/Updated : os_by_language\dataset\ko\LC_MESSAGES-apt-utils-ko.csv
# Created/Updated : os_by_language\dataset\ku\LC_MESSAGES-apt-utils-ku.csv
# Created/Updated : os_by_language\dataset\lt\LC_MESSAGES-apt-utils-lt.csv
# Created/Updated : os_by_language\dataset\mr\LC_MESSAGES-apt-utils-mr.csv
# Created/Updated : os_by_language\dataset\ms\LC_MESSAGES-apt-utils-ms.csv
# Created/Updated : os_by_language\dataset\ne\LC_MESSAGES-apt-utils-ne.csv
# Program interrupted by the user

# %% [markdown]
# # Resetting metadata of the dataset if required
# Uncomment the desired action to perform and run the cell.

# %%
collector.empty_archive_files()
collector.empty_updated_files()
#collector.reset_metadata()
