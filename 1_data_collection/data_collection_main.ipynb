# %% [markdown]
# # Data collection
#
# Use of Weblate API to automatically collect, store and update desired translations on the website Weblate.

# %% [markdown]
# # Importing annex useful functions

# %%
# Personal libraries
import importlib
import data_collection_functions
from data_collection_functions import get_all_translations

# %%
importlib.reload(data_collection_functions)
from data_collection_functions import get_all_translations

# %% [markdown]
# # Weblate projects
# Given a list of projects (or of keywords contained in the desired project names), one can download all its translations, in all languages using the function ``get_all_translations`` function :

# %%
# list of weblate apis and the associated desired project. when ALL : all the projects will be downloaded
wanted_projects = ["ubuntu", "debian"]
get_all_translations("https://hosted.weblate.org/api/", "wlu_F8mRZZeJG9OZ4Y3NfGW6lakufaKJPu7IQFwI", wanted_projects)

# %% [markdown]
# # openSUSE translations
# openSUSE uses its own translation website, but it is also based on the Weblate API. Hence, it is possible to quickly adapt the previous code to collect all the translation of the software, that are numerous.

# %%
# list of weblate apis and the associated desired project. when ALL : all the projects will be downloaded
wanted_projects = "ALL'"
get_all_translations("https://l10n.opensuse.org/api/", None, wanted_projects)
# Out:
# You're using Windows.
# Performing system check...
# ###########################
#
# NordVPN installation check: ✓
# NordVPN service check: ✓
# Opening NordVPN app and disconnecting if necessary...
# NordVPN app launched: ✓
# #####################################
#
# You've entered a list of connection options. Checking list...
#
#
# Saving settings in project folder...
#
#
# Done!
#
# File being checked :  by_language\ar\libgettextdemo-master-ar.csv
# ['libgettextdemo-master-ar.csv'] already up-to-date
# File being checked :  by_language\ca\libgettextdemo-master-ca.csv
# ['libgettextdemo-master-ca.csv'] already up-to-date
# File being checked :  by_language\zh_CN\libgettextdemo-master-zh_CN.csv
# ['libgettextdemo-master-zh_CN.csv'] already up-to-date
# File being checked :  by_language\zh_TW\libgettextdemo-master-zh_TW.csv
# ['libgettextdemo-master-zh_TW.csv'] already up-to-date
# File being checked :  by_language\cs\libgettextdemo-glossary-cs.csv
# ['libgettextdemo-glossary-cs.csv', 'libgettextdemo-master-cs.csv'] already up-to-date
# File being checked :  by_language\nl\libgettextdemo-master-nl.csv
# ['libgettextdemo-master-nl.csv'] already up-to-date
# File being checked :  by_language\et\libgettextdemo-master-et.csv
# ['libgettextdemo-master-et.csv'] already up-to-date
# File being checked :  by_language\fi\libgettextdemo-master-fi.csv
# ['libgettextdemo-master-fi.csv'] already up-to-date
# File being checked :  by_language\fr\libgettextdemo-master-fr.csv
# ['libgettextdemo-master-fr.csv'] already up-to-date
# File being checked :  by_language\de\libgettextdemo-master-de.csv
# ['libgettextdemo-master-de.csv'] already up-to-date
# File being checked :  by_language\hi\libgettextdemo-master-hi.csv
# ['libgettextdemo-master-hi.csv'] already up-to-date
# File being checked :  by_language\hu\libgettextdemo-master-hu.csv
# libgettextdemo-master-hu.csv is empty
# File being checked :  by_language\id\libgettextdemo-master-id.csv
# ['libgettextdemo-master-id.csv'] already up-to-date
# File being checked :  by_language\it\libgettextdemo-master-it.csv
# ['libgettextdemo-master-it.csv'] already up-to-date
# File being checked :  by_language\ja\libgettextdemo-master-ja.csv
# ['libgettextdemo-master-ja.csv'] already up-to-date
# File being checked :  by_language\ko\libgettextdemo-master-ko.csv
# ['libgettextdemo-master-ko.csv'] already up-to-date
# File being checked :  by_language\nn\libgettextdemo-master-nn.csv
# ['libgettextdemo-master-nn.csv'] already up-to-date
# File being checked :  by_language\fa\libgettextdemo-master-fa.csv
# ['libgettextdemo-master-fa.csv'] already up-to-date
# File being checked :  by_language\pl\libgettextdemo-master-pl.csv
# ['libgettextdemo-master-pl.csv'] already up-to-date
# File being checked :  by_language\pt_BR\libgettextdemo-master-pt_BR.csv
# ['libgettextdemo-master-pt_BR.csv'] already up-to-date
# File being checked :  by_language\ru\libgettextdemo-master-ru.csv
# ['libgettextdemo-master-ru.csv'] already up-to-date
# File being checked :  by_language\si\libgettextdemo-master-si.csv
# libgettextdemo-master-si.csv is empty
# File being checked :  by_language\es\libgettextdemo-master-es.csv
# ['libgettextdemo-master-es.csv'] already up-to-date
# File being checked :  by_language\sv\libgettextdemo-master-sv.csv
# ['libgettextdemo-master-sv.csv'] already up-to-date
# File being checked :  by_language\uk\libgettextdemo-master-uk.csv
# ['libgettextdemo-master-uk.csv'] already up-to-date
# Request failed: 429 - {"detail":"Request was throttled. Expected available in 82555 seconds."}
# Too many requests, changing VPN
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Your current ip-address is: 90.126.44.167
#
# Connecting you to Bosnia and Herzegovina ...
#
# your new ip-address is: 185.212.111.65
#
# Done! Enjoy your new server.
#
# File being checked :  by_language\ar\eiciel-glossary-ar.csv
# eiciel-glossary-ar.csv is empty
# Downloaded : by_language\ar\eiciel-master-ar.csv
# File being checked :  by_language\ca\eiciel-glossary-ca.csv
# eiciel-glossary-ca.csv is empty
# Downloaded : by_language\ca\eiciel-master-ca.csv
# File being checked :  by_language\zh_CN\eiciel-glossary-zh_CN.csv
# eiciel-glossary-zh_CN.csv is empty
# Downloaded : by_language\zh_CN\eiciel-master-zh_CN.csv
# File being checked :  by_language\zh_TW\eiciel-glossary-zh_TW.csv
# eiciel-glossary-zh_TW.csv is empty
# Downloaded : by_language\zh_TW\eiciel-master-zh_TW.csv
# File being checked :  by_language\cs\eiciel-glossary-cs.csv
# eiciel-glossary-cs.csv is empty
# Downloaded : by_language\cs\eiciel-master-cs.csv
# File being checked :  by_language\da\eiciel-glossary-da.csv
# eiciel-glossary-da.csv is empty
# Downloaded : by_language\da\eiciel-master-da.csv
# File being checked :  by_language\nl\eiciel-glossary-nl.csv
# eiciel-glossary-nl.csv is empty
# Downloaded : by_language\nl\eiciel-master-nl.csv
# File being checked :  by_language\enm\eiciel-glossary-enm.csv
# eiciel-glossary-enm.csv is empty
# eiciel-master-enm.csv is empty
# File being checked :  by_language\en_GB\eiciel-glossary-en_GB.csv
# eiciel-glossary-en_GB.csv is empty
# Downloaded : by_language\en_GB\eiciel-master-en_GB.csv
# File being checked :  by_language\en_US\eiciel-glossary-en_US.csv
# eiciel-glossary-en_US.csv is empty
# Downloaded : by_language\en_US\eiciel-master-en_US.csv
# File being checked :  by_language\et\eiciel-glossary-et.csv
# eiciel-glossary-et.csv is empty
# Downloaded : by_language\et\eiciel-master-et.csv
# File being checked :  by_language\fi\eiciel-glossary-fi.csv
# eiciel-glossary-fi.csv is empty
# Downloaded : by_language\fi\eiciel-master-fi.csv
# File being checked :  by_language\fr\eiciel-glossary-fr.csv
# eiciel-glossary-fr.csv is empty
# Downloaded : by_language\fr\eiciel-master-fr.csv
# File being checked :  by_language\ka\eiciel-glossary-ka.csv
# eiciel-glossary-ka.csv is empty
# Downloaded : by_language\ka\eiciel-master-ka.csv
# File being checked :  by_language\de\eiciel-glossary-de.csv
# eiciel-glossary-de.csv is empty
# Downloaded : by_language\de\eiciel-master-de.csv
# File being checked :  by_language\hi\eiciel-glossary-hi.csv
# eiciel-glossary-hi.csv is empty
# Downloaded : by_language\hi\eiciel-master-hi.csv
# File being checked :  by_language\hu\eiciel-glossary-hu.csv
# eiciel-glossary-hu.csv is empty
# Downloaded : by_language\hu\eiciel-master-hu.csv
# File being checked :  by_language\id\eiciel-glossary-id.csv
# eiciel-glossary-id.csv is empty
# Downloaded : by_language\id\eiciel-master-id.csv
# File being checked :  by_language\it\eiciel-glossary-it.csv
# eiciel-glossary-it.csv is empty
# Downloaded : by_language\it\eiciel-master-it.csv
# File being checked :  by_language\ja\eiciel-glossary-ja.csv
# eiciel-glossary-ja.csv is empty
# Downloaded : by_language\ja\eiciel-master-ja.csv
# File being checked :  by_language\ko\eiciel-glossary-ko.csv
# eiciel-glossary-ko.csv is empty
# Downloaded : by_language\ko\eiciel-master-ko.csv
# File being checked :  by_language\nn\eiciel-glossary-nn.csv
# eiciel-glossary-nn.csv is empty
# eiciel-master-nn.csv is empty
# File being checked :  by_language\ie\eiciel-glossary-ie.csv
# eiciel-glossary-ie.csv is empty
# Downloaded : by_language\ie\eiciel-master-ie.csv
# File being checked :  by_language\fa\eiciel-glossary-fa.csv
# eiciel-glossary-fa.csv is empty
# Downloaded : by_language\fa\eiciel-master-fa.csv
# File being checked :  by_language\pl\eiciel-glossary-pl.csv
# eiciel-glossary-pl.csv is empty
# Downloaded : by_language\pl\eiciel-master-pl.csv
# File being checked :  by_language\pt_BR\eiciel-glossary-pt_BR.csv
# eiciel-glossary-pt_BR.csv is empty
# Downloaded : by_language\pt_BR\eiciel-master-pt_BR.csv
# File being checked :  by_language\pt_PT\eiciel-glossary-pt_PT.csv
# eiciel-glossary-pt_PT.csv is empty
# Downloaded : by_language\pt_PT\eiciel-master-pt_PT.csv
# File being checked :  by_language\ru\eiciel-glossary-ru.csv
# eiciel-glossary-ru.csv is empty
# Downloaded : by_language\ru\eiciel-master-ru.csv
# File being checked :  by_language\si\eiciel-glossary-si.csv
# eiciel-glossary-si.csv is empty
# eiciel-master-si.csv is empty
# File being checked :  by_language\es\eiciel-glossary-es.csv
# eiciel-glossary-es.csv is empty
# Downloaded : by_language\es\eiciel-master-es.csv
# File being checked :  by_language\sv\eiciel-glossary-sv.csv
# eiciel-glossary-sv.csv is empty
# Downloaded : by_language\sv\eiciel-master-sv.csv
# File being checked :  by_language\uk\eiciel-glossary-uk.csv
# eiciel-glossary-uk.csv is empty
# Downloaded : by_language\uk\eiciel-master-uk.csv
# File being checked :  by_language\sq\libgnomesu-glossary-sq.csv
# libgnomesu-glossary-sq.csv is empty
# Downloaded : by_language\sq\libgnomesu-master-sq.csv
# File being checked :  by_language\ar\libgnomesu-glossary-ar.csv
# libgnomesu-glossary-ar.csv is empty
# Downloaded : by_language\ar\libgnomesu-master-ar.csv
# File being checked :  by_language\az\libgnomesu-glossary-az.csv
# libgnomesu-glossary-az.csv is empty
# Downloaded : by_language\az\libgnomesu-master-az.csv
# File being checked :  by_language\eu\libgnomesu-glossary-eu.csv
# libgnomesu-glossary-eu.csv is empty
# Downloaded : by_language\eu\libgnomesu-master-eu.csv
# File being checked :  by_language\bs\libgnomesu-glossary-bs.csv
# libgnomesu-glossary-bs.csv is empty
# Downloaded : by_language\bs\libgnomesu-master-bs.csv
# File being checked :  by_language\bg\libgnomesu-glossary-bg.csv
# libgnomesu-glossary-bg.csv is empty
# Downloaded : by_language\bg\libgnomesu-master-bg.csv
# File being checked :  by_language\ca\libgnomesu-glossary-ca.csv
# libgnomesu-glossary-ca.csv is empty
# Downloaded : by_language\ca\libgnomesu-master-ca.csv
# File being checked :  by_language\zh_CN\libgnomesu-glossary-zh_CN.csv
# libgnomesu-glossary-zh_CN.csv is empty
# Downloaded : by_language\zh_CN\libgnomesu-master-zh_CN.csv
# File being checked :  by_language\zh_TW\libgnomesu-glossary-zh_TW.csv
# libgnomesu-glossary-zh_TW.csv is empty
# Downloaded : by_language\zh_TW\libgnomesu-master-zh_TW.csv
# File being checked :  by_language\hr\libgnomesu-glossary-hr.csv
# libgnomesu-glossary-hr.csv is empty
# Downloaded : by_language\hr\libgnomesu-master-hr.csv
# File being checked :  by_language\cs\libgnomesu-glossary-cs.csv
# libgnomesu-glossary-cs.csv is empty
# Downloaded : by_language\cs\libgnomesu-master-cs.csv
# File being checked :  by_language\da\libgnomesu-glossary-da.csv
# libgnomesu-glossary-da.csv is empty
# Downloaded : by_language\da\libgnomesu-master-da.csv
# File being checked :  by_language\nl\libgnomesu-glossary-nl.csv
# libgnomesu-glossary-nl.csv is empty
# Downloaded : by_language\nl\libgnomesu-master-nl.csv
# File being checked :  by_language\en_CA\libgnomesu-glossary-en_CA.csv
# libgnomesu-glossary-en_CA.csv is empty
# Downloaded : by_language\en_CA\libgnomesu-master-en_CA.csv
# File being checked :  by_language\en_GB\libgnomesu-glossary-en_GB.csv
# libgnomesu-glossary-en_GB.csv is empty
# Downloaded : by_language\en_GB\libgnomesu-master-en_GB.csv
# File being checked :  by_language\fi\libgnomesu-glossary-fi.csv
# libgnomesu-glossary-fi.csv is empty
# Downloaded : by_language\fi\libgnomesu-master-fi.csv
# File being checked :  by_language\fr\libgnomesu-glossary-fr.csv
# libgnomesu-glossary-fr.csv is empty
# Downloaded : by_language\fr\libgnomesu-master-fr.csv
# File being checked :  by_language\ka\libgnomesu-glossary-ka.csv
# libgnomesu-glossary-ka.csv is empty
# Downloaded : by_language\ka\libgnomesu-master-ka.csv
# File being checked :  by_language\de\libgnomesu-glossary-de.csv
# libgnomesu-glossary-de.csv is empty
# Downloaded : by_language\de\libgnomesu-master-de.csv
# File being checked :  by_language\el\libgnomesu-glossary-el.csv
# libgnomesu-glossary-el.csv is empty
# Downloaded : by_language\el\libgnomesu-master-el.csv
# File being checked :  by_language\gu\libgnomesu-glossary-gu.csv
# libgnomesu-glossary-gu.csv is empty
# Downloaded : by_language\gu\libgnomesu-master-gu.csv
# File being checked :  by_language\hi\libgnomesu-glossary-hi.csv
# libgnomesu-glossary-hi.csv is empty
# Downloaded : by_language\hi\libgnomesu-master-hi.csv
# File being checked :  by_language\hu\libgnomesu-glossary-hu.csv
# libgnomesu-glossary-hu.csv is empty
# Downloaded : by_language\hu\libgnomesu-master-hu.csv
# File being checked :  by_language\id\libgnomesu-glossary-id.csv
# libgnomesu-glossary-id.csv is empty
# Downloaded : by_language\id\libgnomesu-master-id.csv
# File being checked :  by_language\it\libgnomesu-glossary-it.csv
# libgnomesu-glossary-it.csv is empty
# Downloaded : by_language\it\libgnomesu-master-it.csv
# File being checked :  by_language\ja\libgnomesu-glossary-ja.csv
# libgnomesu-glossary-ja.csv is empty
# Downloaded : by_language\ja\libgnomesu-master-ja.csv
# File being checked :  by_language\rw\libgnomesu-glossary-rw.csv
# libgnomesu-glossary-rw.csv is empty
# Downloaded : by_language\rw\libgnomesu-master-rw.csv
# File being checked :  by_language\ko\libgnomesu-glossary-ko.csv
# libgnomesu-glossary-ko.csv is empty
# Downloaded : by_language\ko\libgnomesu-master-ko.csv
# File being checked :  by_language\lv\libgnomesu-glossary-lv.csv
# libgnomesu-glossary-lv.csv is empty
# Downloaded : by_language\lv\libgnomesu-master-lv.csv
# File being checked :  by_language\lt\libgnomesu-glossary-lt.csv
# ['libgnomesu-glossary-lt.csv', 'libgnomesu-master-lt.csv'] already up-to-date
# File being checked :  by_language\mk\libgnomesu-glossary-mk.csv
# libgnomesu-glossary-mk.csv is empty
# Downloaded : by_language\mk\libgnomesu-master-mk.csv
# File being checked :  by_language\ms\libgnomesu-glossary-ms.csv
# libgnomesu-glossary-ms.csv is empty
# Downloaded : by_language\ms\libgnomesu-master-ms.csv
# File being checked :  by_language\ne\libgnomesu-glossary-ne.csv
# libgnomesu-glossary-ne.csv is empty
# Downloaded : by_language\ne\libgnomesu-master-ne.csv
# File being checked :  by_language\nb\libgnomesu-glossary-nb.csv
# libgnomesu-glossary-nb.csv is empty
# Downloaded : by_language\nb\libgnomesu-master-nb.csv
# File being checked :  by_language\nn\libgnomesu-glossary-nn.csv
# libgnomesu-glossary-nn.csv is empty
# libgnomesu-master-nn.csv is empty
# File being checked :  by_language\ie\libgnomesu-glossary-ie.csv
# libgnomesu-glossary-ie.csv is empty
# Downloaded : by_language\ie\libgnomesu-master-ie.csv
# File being checked :  by_language\fa\libgnomesu-glossary-fa.csv
# libgnomesu-glossary-fa.csv is empty
# Downloaded : by_language\fa\libgnomesu-master-fa.csv
# File being checked :  by_language\pl\libgnomesu-glossary-pl.csv
# libgnomesu-glossary-pl.csv is empty
# Downloaded : by_language\pl\libgnomesu-master-pl.csv
# File being checked :  by_language\pt\libgnomesu-glossary-pt.csv
# libgnomesu-glossary-pt.csv is empty
# Downloaded : by_language\pt\libgnomesu-master-pt.csv
# File being checked :  by_language\pt_BR\libgnomesu-glossary-pt_BR.csv
# libgnomesu-glossary-pt_BR.csv is empty
# Downloaded : by_language\pt_BR\libgnomesu-master-pt_BR.csv
# File being checked :  by_language\pa\libgnomesu-glossary-pa.csv
# libgnomesu-glossary-pa.csv is empty
# Downloaded : by_language\pa\libgnomesu-master-pa.csv
# File being checked :  by_language\ru\libgnomesu-glossary-ru.csv
# libgnomesu-glossary-ru.csv is empty
# Downloaded : by_language\ru\libgnomesu-master-ru.csv
# File being checked :  by_language\sr\libgnomesu-glossary-sr.csv
# libgnomesu-glossary-sr.csv is empty
# Downloaded : by_language\sr\libgnomesu-master-sr.csv
# File being checked :  by_language\sr@latin\libgnomesu-glossary-sr@latin.csv
# libgnomesu-glossary-sr@latin.csv is empty
# Downloaded : by_language\sr@latin\libgnomesu-master-sr@latin.csv
# File being checked :  by_language\si\libgnomesu-glossary-si.csv
# libgnomesu-glossary-si.csv is empty
# libgnomesu-master-si.csv is empty
# File being checked :  by_language\sk\libgnomesu-glossary-sk.csv
# libgnomesu-glossary-sk.csv is empty
# Downloaded : by_language\sk\libgnomesu-master-sk.csv
# File being checked :  by_language\es\libgnomesu-glossary-es.csv
# libgnomesu-glossary-es.csv is empty
# Downloaded : by_language\es\libgnomesu-master-es.csv
# File being checked :  by_language\sv\libgnomesu-glossary-sv.csv
# libgnomesu-glossary-sv.csv is empty
# Downloaded : by_language\sv\libgnomesu-master-sv.csv
# File being checked :  by_language\tr\libgnomesu-glossary-tr.csv
# libgnomesu-glossary-tr.csv is empty
# Downloaded : by_language\tr\libgnomesu-master-tr.csv
# File being checked :  by_language\uk\libgnomesu-glossary-uk.csv
# libgnomesu-glossary-uk.csv is empty
# Downloaded : by_language\uk\libgnomesu-master-uk.csv
# File being checked :  by_language\vi\libgnomesu-glossary-vi.csv
# libgnomesu-glossary-vi.csv is empty
# Downloaded : by_language\vi\libgnomesu-master-vi.csv
# File being checked :  by_language\af\libstorage-sle-12-sp4-af.csv
# ['libstorage-sle-12-sp4-af.csv', 'libstorage-sle-12-sp5-af.csv', 'libstorage-glossary-af.csv', 'libstorage-ng-sle-15-sp1-af.csv', 'libstorage-ng-master-af.csv'] already up-to-date
# File being checked :  by_language\ar\libstorage-sle-12-sp4-ar.csv
# ['libstorage-sle-12-sp4-ar.csv', 'libstorage-sle-12-sp5-ar.csv', 'libstorage-glossary-ar.csv', 'libstorage-ng-sle-15-sp1-ar.csv', 'libstorage-ng-master-ar.csv'] already up-to-date
# File being checked :  by_language\eu\libstorage-sle-12-sp4-eu.csv
# libstorage-sle-12-sp4-eu.csv is empty
# libstorage-sle-12-sp5-eu.csv is empty
# libstorage-glossary-eu.csv is empty
# libstorage-ng-sle-15-sp1-eu.csv is empty
# libstorage-ng-master-eu.csv is empty
# File being checked :  by_language\be\libstorage-sle-12-sp4-be.csv
# ['libstorage-sle-12-sp4-be.csv', 'libstorage-sle-12-sp5-be.csv', 'libstorage-glossary-be.csv', 'libstorage-ng-sle-15-sp1-be.csv', 'libstorage-ng-master-be.csv'] already up-to-date
# File being checked :  by_language\bn\libstorage-sle-12-sp4-bn.csv
# ['libstorage-sle-12-sp4-bn.csv', 'libstorage-sle-12-sp5-bn.csv', 'libstorage-glossary-bn.csv', 'libstorage-ng-sle-15-sp1-bn.csv', 'libstorage-ng-master-bn.csv'] already up-to-date
# File being checked :  by_language\bs\libstorage-sle-12-sp4-bs.csv
# ['libstorage-sle-12-sp4-bs.csv', 'libstorage-sle-12-sp5-bs.csv', 'libstorage-glossary-bs.csv', 'libstorage-ng-sle-15-sp1-bs.csv', 'libstorage-ng-master-bs.csv'] already up-to-date
# File being checked :  by_language\bg\libstorage-sle-12-sp4-bg.csv
# ['libstorage-sle-12-sp4-bg.csv', 'libstorage-sle-12-sp5-bg.csv', 'libstorage-glossary-bg.csv', 'libstorage-ng-sle-15-sp1-bg.csv', 'libstorage-ng-master-bg.csv'] already up-to-date
# File being checked :  by_language\ca\libstorage-sle-12-sp4-ca.csv
# ['libstorage-sle-12-sp4-ca.csv', 'libstorage-sle-12-sp5-ca.csv', 'libstorage-glossary-ca.csv', 'libstorage-ng-sle-15-sp1-ca.csv', 'libstorage-ng-master-ca.csv'] already up-to-date
# File being checked :  by_language\zh_CN\libstorage-sle-12-sp4-zh_CN.csv
# ['libstorage-sle-12-sp4-zh_CN.csv', 'libstorage-sle-12-sp5-zh_CN.csv', 'libstorage-glossary-zh_CN.csv', 'libstorage-ng-sle-15-sp1-zh_CN.csv', 'libstorage-ng-master-zh_CN.csv'] already up-to-date
# File being checked :  by_language\zh_TW\libstorage-sle-12-sp4-zh_TW.csv
# ['libstorage-sle-12-sp4-zh_TW.csv', 'libstorage-sle-12-sp5-zh_TW.csv', 'libstorage-glossary-zh_TW.csv', 'libstorage-ng-sle-15-sp1-zh_TW.csv', 'libstorage-ng-master-zh_TW.csv'] already up-to-date
# File being checked :  by_language\hr\libstorage-sle-12-sp4-hr.csv
# ['libstorage-sle-12-sp4-hr.csv', 'libstorage-sle-12-sp5-hr.csv', 'libstorage-glossary-hr.csv', 'libstorage-ng-sle-15-sp1-hr.csv', 'libstorage-ng-master-hr.csv'] already up-to-date
# File being checked :  by_language\cs\libstorage-sle-12-sp4-cs.csv
# ['libstorage-sle-12-sp4-cs.csv', 'libstorage-sle-12-sp5-cs.csv', 'libstorage-glossary-cs.csv', 'libstorage-ng-sle-15-sp1-cs.csv', 'libstorage-ng-master-cs.csv'] already up-to-date
# File being checked :  by_language\da\libstorage-sle-12-sp4-da.csv
# ['libstorage-sle-12-sp4-da.csv', 'libstorage-sle-12-sp5-da.csv', 'libstorage-glossary-da.csv', 'libstorage-ng-sle-15-sp1-da.csv', 'libstorage-ng-master-da.csv'] already up-to-date
# File being checked :  by_language\nl\libstorage-sle-12-sp4-nl.csv
# ['libstorage-sle-12-sp4-nl.csv', 'libstorage-sle-12-sp5-nl.csv', 'libstorage-glossary-nl.csv', 'libstorage-ng-sle-15-sp1-nl.csv', 'libstorage-ng-master-nl.csv'] already up-to-date
# File being checked :  by_language\en_GB\libstorage-sle-12-sp4-en_GB.csv
# ['libstorage-sle-12-sp4-en_GB.csv', 'libstorage-sle-12-sp5-en_GB.csv', 'libstorage-glossary-en_GB.csv', 'libstorage-ng-sle-15-sp1-en_GB.csv', 'libstorage-ng-master-en_GB.csv'] already up-to-date
# File being checked :  by_language\en_US\libstorage-sle-12-sp4-en_US.csv
# ['libstorage-sle-12-sp4-en_US.csv', 'libstorage-sle-12-sp5-en_US.csv', 'libstorage-glossary-en_US.csv', 'libstorage-ng-sle-15-sp1-en_US.csv', 'libstorage-ng-master-en_US.csv'] already up-to-date
# File being checked :  by_language\eo\libstorage-sle-12-sp4-eo.csv
# libstorage-sle-12-sp4-eo.csv is empty
# libstorage-sle-12-sp5-eo.csv is empty
# libstorage-glossary-eo.csv is empty
# libstorage-ng-sle-15-sp1-eo.csv is empty
# libstorage-ng-master-eo.csv is empty
# File being checked :  by_language\et\libstorage-sle-12-sp4-et.csv
# ['libstorage-sle-12-sp4-et.csv', 'libstorage-sle-12-sp5-et.csv', 'libstorage-glossary-et.csv', 'libstorage-ng-sle-15-sp1-et.csv', 'libstorage-ng-master-et.csv'] already up-to-date
# File being checked :  by_language\fi\libstorage-sle-12-sp4-fi.csv
# ['libstorage-sle-12-sp4-fi.csv', 'libstorage-sle-12-sp5-fi.csv', 'libstorage-glossary-fi.csv', 'libstorage-ng-sle-15-sp1-fi.csv', 'libstorage-ng-master-fi.csv'] already up-to-date
# File being checked :  by_language\fr\libstorage-sle-12-sp4-fr.csv
# ['libstorage-sle-12-sp4-fr.csv', 'libstorage-sle-12-sp5-fr.csv', 'libstorage-glossary-fr.csv', 'libstorage-ng-sle-15-sp1-fr.csv', 'libstorage-ng-master-fr.csv'] already up-to-date
# File being checked :  by_language\gl\libstorage-sle-12-sp4-gl.csv
# ['libstorage-sle-12-sp4-gl.csv', 'libstorage-sle-12-sp5-gl.csv', 'libstorage-glossary-gl.csv', 'libstorage-ng-sle-15-sp1-gl.csv', 'libstorage-ng-master-gl.csv'] already up-to-date
# File being checked :  by_language\ka\libstorage-sle-12-sp4-ka.csv
# ['libstorage-sle-12-sp4-ka.csv', 'libstorage-sle-12-sp5-ka.csv', 'libstorage-glossary-ka.csv', 'libstorage-ng-sle-15-sp1-ka.csv', 'libstorage-ng-master-ka.csv'] already up-to-date
# File being checked :  by_language\de\libstorage-sle-12-sp4-de.csv
# ['libstorage-sle-12-sp4-de.csv', 'libstorage-sle-12-sp5-de.csv', 'libstorage-glossary-de.csv', 'libstorage-ng-sle-15-sp1-de.csv', 'libstorage-ng-master-de.csv'] already up-to-date
# File being checked :  by_language\nds\libstorage-sle-12-sp4-nds.csv
# libstorage-sle-12-sp4-nds.csv is empty
# libstorage-sle-12-sp5-nds.csv is empty
# libstorage-glossary-nds.csv is empty
# libstorage-ng-sle-15-sp1-nds.csv is empty
# libstorage-ng-master-nds.csv is empty
# File being checked :  by_language\el\libstorage-sle-12-sp4-el.csv
# ['libstorage-sle-12-sp4-el.csv', 'libstorage-sle-12-sp5-el.csv', 'libstorage-glossary-el.csv', 'libstorage-ng-sle-15-sp1-el.csv', 'libstorage-ng-master-el.csv'] already up-to-date
# File being checked :  by_language\gu\libstorage-sle-12-sp4-gu.csv
# ['libstorage-sle-12-sp4-gu.csv', 'libstorage-sle-12-sp5-gu.csv', 'libstorage-glossary-gu.csv', 'libstorage-ng-sle-15-sp1-gu.csv', 'libstorage-ng-master-gu.csv'] already up-to-date
# File being checked :  by_language\he\libstorage-sle-12-sp4-he.csv
# ['libstorage-sle-12-sp4-he.csv', 'libstorage-sle-12-sp5-he.csv', 'libstorage-glossary-he.csv', 'libstorage-ng-sle-15-sp1-he.csv', 'libstorage-ng-master-he.csv'] already up-to-date
# File being checked :  by_language\hi\libstorage-sle-12-sp4-hi.csv
# ['libstorage-sle-12-sp4-hi.csv', 'libstorage-sle-12-sp5-hi.csv', 'libstorage-glossary-hi.csv', 'libstorage-ng-sle-15-sp1-hi.csv', 'libstorage-ng-master-hi.csv'] already up-to-date
# File being checked :  by_language\hu\libstorage-sle-12-sp4-hu.csv
# ['libstorage-sle-12-sp4-hu.csv', 'libstorage-sle-12-sp5-hu.csv', 'libstorage-glossary-hu.csv', 'libstorage-ng-sle-15-sp1-hu.csv', 'libstorage-ng-master-hu.csv'] already up-to-date
# File being checked :  by_language\id\libstorage-sle-12-sp4-id.csv
# ['libstorage-sle-12-sp4-id.csv', 'libstorage-sle-12-sp5-id.csv', 'libstorage-glossary-id.csv', 'libstorage-ng-sle-15-sp1-id.csv', 'libstorage-ng-master-id.csv'] already up-to-date
# File being checked :  by_language\it\libstorage-sle-12-sp4-it.csv
# ['libstorage-sle-12-sp4-it.csv', 'libstorage-sle-12-sp5-it.csv', 'libstorage-glossary-it.csv', 'libstorage-ng-sle-15-sp1-it.csv', 'libstorage-ng-master-it.csv'] already up-to-date
# File being checked :  by_language\ja\libstorage-sle-12-sp4-ja.csv
# ['libstorage-sle-12-sp4-ja.csv', 'libstorage-sle-12-sp5-ja.csv', 'libstorage-glossary-ja.csv', 'libstorage-ng-sle-15-sp1-ja.csv', 'libstorage-ng-master-ja.csv'] already up-to-date
# File being checked :  by_language\km\libstorage-sle-12-sp4-km.csv
# ['libstorage-sle-12-sp4-km.csv', 'libstorage-sle-12-sp5-km.csv', 'libstorage-glossary-km.csv', 'libstorage-ng-sle-15-sp1-km.csv', 'libstorage-ng-master-km.csv'] already up-to-date
# File being checked :  by_language\ko\libstorage-sle-12-sp4-ko.csv
# ['libstorage-sle-12-sp4-ko.csv', 'libstorage-sle-12-sp5-ko.csv', 'libstorage-glossary-ko.csv', 'libstorage-ng-sle-15-sp1-ko.csv', 'libstorage-ng-master-ko.csv'] already up-to-date
# File being checked :  by_language\ku\libstorage-sle-12-sp4-ku.csv
# ['libstorage-sle-12-sp4-ku.csv', 'libstorage-sle-12-sp5-ku.csv', 'libstorage-glossary-ku.csv', 'libstorage-ng-sle-15-sp1-ku.csv', 'libstorage-ng-master-ku.csv'] already up-to-date
# File being checked :  by_language\lo\libstorage-sle-12-sp4-lo.csv
# libstorage-sle-12-sp4-lo.csv is empty
# libstorage-sle-12-sp5-lo.csv is empty
# libstorage-glossary-lo.csv is empty
# libstorage-ng-sle-15-sp1-lo.csv is empty
# libstorage-ng-master-lo.csv is empty
# File being checked :  by_language\lt\libstorage-sle-12-sp4-lt.csv
# ['libstorage-sle-12-sp4-lt.csv', 'libstorage-sle-12-sp5-lt.csv', 'libstorage-glossary-lt.csv', 'libstorage-ng-sle-15-sp1-lt.csv', 'libstorage-ng-master-lt.csv'] already up-to-date
# File being checked :  by_language\mk\libstorage-sle-12-sp4-mk.csv
# ['libstorage-sle-12-sp4-mk.csv', 'libstorage-sle-12-sp5-mk.csv', 'libstorage-glossary-mk.csv', 'libstorage-ng-sle-15-sp1-mk.csv', 'libstorage-ng-master-mk.csv'] already up-to-date
# File being checked :  by_language\mr\libstorage-sle-12-sp4-mr.csv
# ['libstorage-sle-12-sp4-mr.csv', 'libstorage-sle-12-sp5-mr.csv', 'libstorage-glossary-mr.csv', 'libstorage-ng-sle-15-sp1-mr.csv', 'libstorage-ng-master-mr.csv'] already up-to-date
# File being checked :  by_language\nb\libstorage-sle-12-sp4-nb.csv
# ['libstorage-sle-12-sp4-nb.csv', 'libstorage-sle-12-sp5-nb.csv', 'libstorage-glossary-nb.csv', 'libstorage-ng-sle-15-sp1-nb.csv', 'libstorage-ng-master-nb.csv'] already up-to-date
# File being checked :  by_language\nn\libstorage-sle-12-sp4-nn.csv
# libstorage-sle-12-sp4-nn.csv is empty
# libstorage-sle-12-sp5-nn.csv is empty
# libstorage-glossary-nn.csv is empty
# libstorage-ng-sle-15-sp1-nn.csv is empty
# libstorage-ng-master-nn.csv is empty
# File being checked :  by_language\fa\libstorage-sle-12-sp4-fa.csv
# libstorage-sle-12-sp4-fa.csv is empty
# libstorage-sle-12-sp5-fa.csv is empty
# libstorage-glossary-fa.csv is empty
# libstorage-ng-sle-15-sp1-fa.csv is empty
# libstorage-ng-master-fa.csv is empty
# File being checked :  by_language\pl\libstorage-sle-12-sp4-pl.csv
# ['libstorage-sle-12-sp4-pl.csv', 'libstorage-sle-12-sp5-pl.csv', 'libstorage-glossary-pl.csv', 'libstorage-ng-sle-15-sp1-pl.csv', 'libstorage-ng-master-pl.csv'] already up-to-date
# File being checked :  by_language\pt\libstorage-sle-12-sp4-pt.csv
# ['libstorage-sle-12-sp4-pt.csv', 'libstorage-sle-12-sp5-pt.csv', 'libstorage-glossary-pt.csv', 'libstorage-ng-sle-15-sp1-pt.csv', 'libstorage-ng-master-pt.csv'] already up-to-date
# File being checked :  by_language\pt_BR\libstorage-sle-12-sp4-pt_BR.csv
# ['libstorage-sle-12-sp4-pt_BR.csv', 'libstorage-sle-12-sp5-pt_BR.csv', 'libstorage-glossary-pt_BR.csv', 'libstorage-ng-sle-15-sp1-pt_BR.csv', 'libstorage-ng-master-pt_BR.csv'] already up-to-date
# File being checked :  by_language\pa\libstorage-sle-12-sp4-pa.csv
# ['libstorage-sle-12-sp4-pa.csv', 'libstorage-sle-12-sp5-pa.csv', 'libstorage-glossary-pa.csv', 'libstorage-ng-sle-15-sp1-pa.csv', 'libstorage-ng-master-pa.csv'] already up-to-date
# File being checked :  by_language\ro\libstorage-sle-12-sp4-ro.csv
# ['libstorage-sle-12-sp4-ro.csv', 'libstorage-sle-12-sp5-ro.csv', 'libstorage-glossary-ro.csv', 'libstorage-ng-sle-15-sp1-ro.csv', 'libstorage-ng-master-ro.csv'] already up-to-date
# File being checked :  by_language\ru\libstorage-sle-12-sp4-ru.csv
# ['libstorage-sle-12-sp4-ru.csv', 'libstorage-sle-12-sp5-ru.csv', 'libstorage-glossary-ru.csv', 'libstorage-ng-sle-15-sp1-ru.csv', 'libstorage-ng-master-ru.csv'] already up-to-date
# File being checked :  by_language\sr\libstorage-sle-12-sp4-sr.csv
# ['libstorage-sle-12-sp4-sr.csv', 'libstorage-sle-12-sp5-sr.csv', 'libstorage-glossary-sr.csv', 'libstorage-ng-sle-15-sp1-sr.csv', 'libstorage-ng-master-sr.csv'] already up-to-date
# File being checked :  by_language\si\libstorage-sle-12-sp4-si.csv
# libstorage-sle-12-sp4-si.csv is empty
# libstorage-sle-12-sp5-si.csv is empty
# libstorage-glossary-si.csv is empty
# libstorage-ng-sle-15-sp1-si.csv is empty
# libstorage-ng-master-si.csv is empty
# File being checked :  by_language\sk\libstorage-sle-12-sp4-sk.csv
# ['libstorage-sle-12-sp4-sk.csv', 'libstorage-sle-12-sp5-sk.csv', 'libstorage-glossary-sk.csv', 'libstorage-ng-sle-15-sp1-sk.csv', 'libstorage-ng-master-sk.csv'] already up-to-date
# File being checked :  by_language\sl\libstorage-sle-12-sp4-sl.csv
# ['libstorage-sle-12-sp4-sl.csv', 'libstorage-sle-12-sp5-sl.csv', 'libstorage-glossary-sl.csv', 'libstorage-ng-sle-15-sp1-sl.csv', 'libstorage-ng-master-sl.csv'] already up-to-date
# File being checked :  by_language\es\libstorage-sle-12-sp4-es.csv
# ['libstorage-sle-12-sp4-es.csv', 'libstorage-sle-12-sp5-es.csv', 'libstorage-glossary-es.csv', 'libstorage-ng-sle-15-sp1-es.csv', 'libstorage-ng-master-es.csv'] already up-to-date
# File being checked :  by_language\sv\libstorage-sle-12-sp4-sv.csv
# ['libstorage-sle-12-sp4-sv.csv', 'libstorage-sle-12-sp5-sv.csv', 'libstorage-glossary-sv.csv', 'libstorage-ng-sle-15-sp1-sv.csv', 'libstorage-ng-master-sv.csv'] already up-to-date
# File being checked :  by_language\tg\libstorage-sle-12-sp4-tg.csv
# ['libstorage-sle-12-sp4-tg.csv', 'libstorage-sle-12-sp5-tg.csv', 'libstorage-glossary-tg.csv', 'libstorage-ng-sle-15-sp1-tg.csv', 'libstorage-ng-master-tg.csv'] already up-to-date
# File being checked :  by_language\ta\libstorage-sle-12-sp4-ta.csv
# ['libstorage-sle-12-sp4-ta.csv', 'libstorage-sle-12-sp5-ta.csv', 'libstorage-glossary-ta.csv', 'libstorage-ng-sle-15-sp1-ta.csv', 'libstorage-ng-master-ta.csv'] already up-to-date
# File being checked :  by_language\th\libstorage-sle-12-sp4-th.csv
# ['libstorage-sle-12-sp4-th.csv', 'libstorage-sle-12-sp5-th.csv', 'libstorage-glossary-th.csv', 'libstorage-ng-sle-15-sp1-th.csv', 'libstorage-ng-master-th.csv'] already up-to-date
# File being checked :  by_language\tr\libstorage-sle-12-sp4-tr.csv
# ['libstorage-sle-12-sp4-tr.csv', 'libstorage-sle-12-sp5-tr.csv', 'libstorage-glossary-tr.csv', 'libstorage-ng-sle-15-sp1-tr.csv', 'libstorage-ng-master-tr.csv'] already up-to-date
# File being checked :  by_language\uk\libstorage-sle-12-sp4-uk.csv
# ['libstorage-sle-12-sp4-uk.csv', 'libstorage-sle-12-sp5-uk.csv', 'libstorage-glossary-uk.csv', 'libstorage-ng-sle-15-sp1-uk.csv', 'libstorage-ng-master-uk.csv'] already up-to-date
# File being checked :  by_language\vi\libstorage-sle-12-sp4-vi.csv
# ['libstorage-sle-12-sp4-vi.csv', 'libstorage-sle-12-sp5-vi.csv', 'libstorage-glossary-vi.csv', 'libstorage-ng-sle-15-sp1-vi.csv', 'libstorage-ng-master-vi.csv'] already up-to-date
# File being checked :  by_language\wa\libstorage-sle-12-sp4-wa.csv
# ['libstorage-sle-12-sp4-wa.csv', 'libstorage-sle-12-sp5-wa.csv', 'libstorage-glossary-wa.csv', 'libstorage-ng-sle-15-sp1-wa.csv', 'libstorage-ng-master-wa.csv'] already up-to-date
# File being checked :  by_language\cy\libstorage-sle-12-sp4-cy.csv
# ['libstorage-sle-12-sp4-cy.csv', 'libstorage-sle-12-sp5-cy.csv', 'libstorage-glossary-cy.csv', 'libstorage-ng-sle-15-sp1-cy.csv', 'libstorage-ng-master-cy.csv'] already up-to-date
# File being checked :  by_language\xh\libstorage-sle-12-sp4-xh.csv
# ['libstorage-sle-12-sp4-xh.csv', 'libstorage-sle-12-sp5-xh.csv', 'libstorage-glossary-xh.csv', 'libstorage-ng-sle-15-sp1-xh.csv', 'libstorage-ng-master-xh.csv'] already up-to-date
# File being checked :  by_language\zu\libstorage-sle-12-sp4-zu.csv
# ['libstorage-sle-12-sp4-zu.csv', 'libstorage-sle-12-sp5-zu.csv', 'libstorage-glossary-zu.csv', 'libstorage-ng-sle-15-sp1-zu.csv', 'libstorage-ng-master-zu.csv'] already up-to-date
# File being checked :  by_language\af\release-notes-opensuse-leap-15_2-af.csv
# ['release-notes-opensuse-leap-15_2-af.csv', 'release-notes-opensuse-leap-15_3-af.csv', 'release-notes-opensuse-leap-15_4-af.csv', 'release-notes-opensuse-leap_15_5-af.csv', 'release-notes-opensuse-leap_15_6-af.csv', 'release-notes-opensuse-glossary-af.csv', 'release-notes-opensuse-master-af.csv'] already up-to-date
# File being checked :  by_language\ar\release-notes-opensuse-leap-15_2-ar.csv
# ['release-notes-opensuse-leap-15_2-ar.csv', 'release-notes-opensuse-leap-15_3-ar.csv', 'release-notes-opensuse-leap-15_4-ar.csv', 'release-notes-opensuse-leap_15_5-ar.csv', 'release-notes-opensuse-leap_15_6-ar.csv', 'release-notes-opensuse-glossary-ar.csv', 'release-notes-opensuse-master-ar.csv'] already up-to-date
# File being checked :  by_language\be\release-notes-opensuse-leap-15_2-be.csv
# ['release-notes-opensuse-leap-15_2-be.csv', 'release-notes-opensuse-leap-15_3-be.csv', 'release-notes-opensuse-leap-15_4-be.csv', 'release-notes-opensuse-leap_15_5-be.csv', 'release-notes-opensuse-leap_15_6-be.csv', 'release-notes-opensuse-glossary-be.csv', 'release-notes-opensuse-master-be.csv'] already up-to-date
# File being checked :  by_language\bn\release-notes-opensuse-leap-15_2-bn.csv
# ['release-notes-opensuse-leap-15_2-bn.csv', 'release-notes-opensuse-leap-15_3-bn.csv', 'release-notes-opensuse-leap-15_4-bn.csv', 'release-notes-opensuse-leap_15_5-bn.csv', 'release-notes-opensuse-leap_15_6-bn.csv', 'release-notes-opensuse-glossary-bn.csv', 'release-notes-opensuse-master-bn.csv'] already up-to-date
# File being checked :  by_language\bg\release-notes-opensuse-leap-15_2-bg.csv
# ['release-notes-opensuse-leap-15_2-bg.csv', 'release-notes-opensuse-leap-15_3-bg.csv', 'release-notes-opensuse-leap-15_4-bg.csv', 'release-notes-opensuse-leap_15_5-bg.csv', 'release-notes-opensuse-leap_15_6-bg.csv', 'release-notes-opensuse-glossary-bg.csv', 'release-notes-opensuse-master-bg.csv'] already up-to-date
# File being checked :  by_language\ca\release-notes-opensuse-leap-15_2-ca.csv
# ['release-notes-opensuse-leap-15_2-ca.csv', 'release-notes-opensuse-leap-15_3-ca.csv', 'release-notes-opensuse-leap-15_4-ca.csv', 'release-notes-opensuse-leap_15_5-ca.csv', 'release-notes-opensuse-leap_15_6-ca.csv', 'release-notes-opensuse-glossary-ca.csv', 'release-notes-opensuse-master-ca.csv'] already up-to-date
# File being checked :  by_language\zh_CN\release-notes-opensuse-leap-15_2-zh_CN.csv
# ['release-notes-opensuse-leap-15_2-zh_CN.csv', 'release-notes-opensuse-leap-15_3-zh_CN.csv', 'release-notes-opensuse-leap-15_4-zh_CN.csv', 'release-notes-opensuse-leap_15_5-zh_CN.csv', 'release-notes-opensuse-leap_15_6-zh_CN.csv', 'release-notes-opensuse-glossary-zh_CN.csv', 'release-notes-opensuse-master-zh_CN.csv'] already up-to-date
# File being checked :  by_language\zh_TW\release-notes-opensuse-leap-15_2-zh_TW.csv
# ['release-notes-opensuse-leap-15_2-zh_TW.csv', 'release-notes-opensuse-leap-15_3-zh_TW.csv', 'release-notes-opensuse-leap-15_4-zh_TW.csv', 'release-notes-opensuse-leap_15_5-zh_TW.csv', 'release-notes-opensuse-leap_15_6-zh_TW.csv', 'release-notes-opensuse-glossary-zh_TW.csv', 'release-notes-opensuse-master-zh_TW.csv'] already up-to-date
# File being checked :  by_language\hr\release-notes-opensuse-leap-15_2-hr.csv
# ['release-notes-opensuse-leap-15_2-hr.csv', 'release-notes-opensuse-leap-15_3-hr.csv', 'release-notes-opensuse-leap-15_4-hr.csv', 'release-notes-opensuse-leap_15_5-hr.csv', 'release-notes-opensuse-leap_15_6-hr.csv', 'release-notes-opensuse-glossary-hr.csv', 'release-notes-opensuse-master-hr.csv'] already up-to-date
# File being checked :  by_language\cs\release-notes-opensuse-leap-15_2-cs.csv
# ['release-notes-opensuse-leap-15_2-cs.csv', 'release-notes-opensuse-leap-15_3-cs.csv', 'release-notes-opensuse-leap-15_4-cs.csv', 'release-notes-opensuse-leap_15_5-cs.csv', 'release-notes-opensuse-leap_15_6-cs.csv', 'release-notes-opensuse-glossary-cs.csv', 'release-notes-opensuse-master-cs.csv'] already up-to-date
# File being checked :  by_language\da\release-notes-opensuse-leap-15_2-da.csv
# ['release-notes-opensuse-leap-15_2-da.csv', 'release-notes-opensuse-leap-15_3-da.csv', 'release-notes-opensuse-leap-15_4-da.csv', 'release-notes-opensuse-leap_15_5-da.csv', 'release-notes-opensuse-leap_15_6-da.csv', 'release-notes-opensuse-glossary-da.csv', 'release-notes-opensuse-master-da.csv'] already up-to-date
# File being checked :  by_language\nl\release-notes-opensuse-leap-15_2-nl.csv
# ['release-notes-opensuse-leap-15_2-nl.csv', 'release-notes-opensuse-leap-15_3-nl.csv', 'release-notes-opensuse-leap-15_4-nl.csv', 'release-notes-opensuse-leap_15_5-nl.csv', 'release-notes-opensuse-leap_15_6-nl.csv', 'release-notes-opensuse-glossary-nl.csv', 'release-notes-opensuse-master-nl.csv'] already up-to-date
# File being checked :  by_language\en_GB\release-notes-opensuse-leap-15_2-en_GB.csv
# ['release-notes-opensuse-leap-15_2-en_GB.csv', 'release-notes-opensuse-leap-15_3-en_GB.csv', 'release-notes-opensuse-leap-15_4-en_GB.csv', 'release-notes-opensuse-leap_15_5-en_GB.csv', 'release-notes-opensuse-leap_15_6-en_GB.csv', 'release-notes-opensuse-glossary-en_GB.csv', 'release-notes-opensuse-master-en_GB.csv'] already up-to-date
# File being checked :  by_language\et\release-notes-opensuse-leap-15_2-et.csv
# ['release-notes-opensuse-leap-15_2-et.csv', 'release-notes-opensuse-leap-15_3-et.csv', 'release-notes-opensuse-leap-15_4-et.csv', 'release-notes-opensuse-leap_15_5-et.csv', 'release-notes-opensuse-leap_15_6-et.csv', 'release-notes-opensuse-glossary-et.csv', 'release-notes-opensuse-master-et.csv'] already up-to-date
# File being checked :  by_language\fi\release-notes-opensuse-leap-15_2-fi.csv
# ['release-notes-opensuse-leap-15_2-fi.csv', 'release-notes-opensuse-leap-15_3-fi.csv', 'release-notes-opensuse-leap-15_4-fi.csv', 'release-notes-opensuse-leap_15_5-fi.csv', 'release-notes-opensuse-leap_15_6-fi.csv', 'release-notes-opensuse-glossary-fi.csv', 'release-notes-opensuse-master-fi.csv'] already up-to-date
# File being checked :  by_language\fr\release-notes-opensuse-leap-15_2-fr.csv
# ['release-notes-opensuse-leap-15_2-fr.csv', 'release-notes-opensuse-leap-15_3-fr.csv', 'release-notes-opensuse-leap-15_4-fr.csv', 'release-notes-opensuse-leap_15_5-fr.csv', 'release-notes-opensuse-leap_15_6-fr.csv', 'release-notes-opensuse-glossary-fr.csv', 'release-notes-opensuse-master-fr.csv'] already up-to-date
# File being checked :  by_language\gl\release-notes-opensuse-leap-15_2-gl.csv
# ['release-notes-opensuse-leap-15_2-gl.csv', 'release-notes-opensuse-leap-15_3-gl.csv', 'release-notes-opensuse-leap-15_4-gl.csv', 'release-notes-opensuse-leap_15_5-gl.csv', 'release-notes-opensuse-leap_15_6-gl.csv', 'release-notes-opensuse-glossary-gl.csv', 'release-notes-opensuse-master-gl.csv'] already up-to-date
# File being checked :  by_language\ka\release-notes-opensuse-leap-15_2-ka.csv
# ['release-notes-opensuse-leap-15_2-ka.csv', 'release-notes-opensuse-leap-15_3-ka.csv', 'release-notes-opensuse-leap-15_4-ka.csv', 'release-notes-opensuse-leap_15_5-ka.csv', 'release-notes-opensuse-leap_15_6-ka.csv', 'release-notes-opensuse-glossary-ka.csv', 'release-notes-opensuse-master-ka.csv'] already up-to-date
# File being checked :  by_language\de\release-notes-opensuse-leap-15_2-de.csv
# ['release-notes-opensuse-leap-15_2-de.csv', 'release-notes-opensuse-leap-15_3-de.csv', 'release-notes-opensuse-leap-15_4-de.csv', 'release-notes-opensuse-leap_15_5-de.csv', 'release-notes-opensuse-leap_15_6-de.csv', 'release-notes-opensuse-glossary-de.csv', 'release-notes-opensuse-master-de.csv'] already up-to-date
# File being checked :  by_language\el\release-notes-opensuse-leap-15_2-el.csv
# ['release-notes-opensuse-leap-15_2-el.csv', 'release-notes-opensuse-leap-15_3-el.csv', 'release-notes-opensuse-leap-15_4-el.csv', 'release-notes-opensuse-leap_15_5-el.csv', 'release-notes-opensuse-leap_15_6-el.csv', 'release-notes-opensuse-glossary-el.csv', 'release-notes-opensuse-master-el.csv'] already up-to-date
# File being checked :  by_language\gu\release-notes-opensuse-leap-15_2-gu.csv
# ['release-notes-opensuse-leap-15_2-gu.csv', 'release-notes-opensuse-leap-15_3-gu.csv', 'release-notes-opensuse-leap-15_4-gu.csv', 'release-notes-opensuse-leap_15_5-gu.csv', 'release-notes-opensuse-leap_15_6-gu.csv', 'release-notes-opensuse-glossary-gu.csv', 'release-notes-opensuse-master-gu.csv'] already up-to-date
# File being checked :  by_language\hi\release-notes-opensuse-leap-15_2-hi.csv
# ['release-notes-opensuse-leap-15_2-hi.csv', 'release-notes-opensuse-leap-15_3-hi.csv', 'release-notes-opensuse-leap-15_4-hi.csv', 'release-notes-opensuse-leap_15_5-hi.csv', 'release-notes-opensuse-leap_15_6-hi.csv', 'release-notes-opensuse-glossary-hi.csv', 'release-notes-opensuse-master-hi.csv'] already up-to-date
# File being checked :  by_language\hu\release-notes-opensuse-leap-15_2-hu.csv
# ['release-notes-opensuse-leap-15_2-hu.csv', 'release-notes-opensuse-leap-15_3-hu.csv', 'release-notes-opensuse-leap-15_4-hu.csv', 'release-notes-opensuse-leap_15_5-hu.csv', 'release-notes-opensuse-leap_15_6-hu.csv', 'release-notes-opensuse-glossary-hu.csv', 'release-notes-opensuse-master-hu.csv'] already up-to-date
# File being checked :  by_language\id\release-notes-opensuse-leap-15_2-id.csv
# ['release-notes-opensuse-leap-15_2-id.csv', 'release-notes-opensuse-leap-15_3-id.csv', 'release-notes-opensuse-leap-15_4-id.csv', 'release-notes-opensuse-leap_15_5-id.csv', 'release-notes-opensuse-leap_15_6-id.csv', 'release-notes-opensuse-glossary-id.csv', 'release-notes-opensuse-master-id.csv'] already up-to-date
# File being checked :  by_language\it\release-notes-opensuse-leap-15_2-it.csv
# ['release-notes-opensuse-leap-15_2-it.csv', 'release-notes-opensuse-leap-15_3-it.csv', 'release-notes-opensuse-leap-15_4-it.csv', 'release-notes-opensuse-leap_15_5-it.csv', 'release-notes-opensuse-leap_15_6-it.csv', 'release-notes-opensuse-glossary-it.csv', 'release-notes-opensuse-master-it.csv'] already up-to-date
# File being checked :  by_language\ja\release-notes-opensuse-leap-15_2-ja.csv
# ['release-notes-opensuse-leap-15_2-ja.csv', 'release-notes-opensuse-leap-15_3-ja.csv', 'release-notes-opensuse-leap-15_4-ja.csv', 'release-notes-opensuse-leap_15_5-ja.csv', 'release-notes-opensuse-leap_15_6-ja.csv', 'release-notes-opensuse-glossary-ja.csv', 'release-notes-opensuse-master-ja.csv'] already up-to-date
# File being checked :  by_language\kab\release-notes-opensuse-leap-15_2-kab.csv
# ['release-notes-opensuse-leap-15_2-kab.csv', 'release-notes-opensuse-leap-15_3-kab.csv', 'release-notes-opensuse-leap-15_4-kab.csv', 'release-notes-opensuse-leap_15_5-kab.csv', 'release-notes-opensuse-leap_15_6-kab.csv', 'release-notes-opensuse-glossary-kab.csv', 'release-notes-opensuse-master-kab.csv'] already up-to-date
# File being checked :  by_language\km\release-notes-opensuse-leap-15_2-km.csv
# ['release-notes-opensuse-leap-15_2-km.csv', 'release-notes-opensuse-leap-15_3-km.csv', 'release-notes-opensuse-leap-15_4-km.csv', 'release-notes-opensuse-leap_15_5-km.csv', 'release-notes-opensuse-leap_15_6-km.csv', 'release-notes-opensuse-glossary-km.csv', 'release-notes-opensuse-master-km.csv'] already up-to-date
# File being checked :  by_language\ko\release-notes-opensuse-leap-15_2-ko.csv
# ['release-notes-opensuse-leap-15_2-ko.csv', 'release-notes-opensuse-leap-15_3-ko.csv', 'release-notes-opensuse-leap-15_4-ko.csv', 'release-notes-opensuse-leap_15_5-ko.csv', 'release-notes-opensuse-leap_15_6-ko.csv', 'release-notes-opensuse-glossary-ko.csv', 'release-notes-opensuse-master-ko.csv'] already up-to-date
# File being checked :  by_language\ku\release-notes-opensuse-leap-15_2-ku.csv
# ['release-notes-opensuse-leap-15_2-ku.csv', 'release-notes-opensuse-leap-15_3-ku.csv', 'release-notes-opensuse-leap-15_4-ku.csv', 'release-notes-opensuse-leap_15_5-ku.csv', 'release-notes-opensuse-leap_15_6-ku.csv', 'release-notes-opensuse-glossary-ku.csv', 'release-notes-opensuse-master-ku.csv'] already up-to-date
# File being checked :  by_language\lt\release-notes-opensuse-leap-15_2-lt.csv
# ['release-notes-opensuse-leap-15_2-lt.csv', 'release-notes-opensuse-leap-15_3-lt.csv', 'release-notes-opensuse-leap-15_4-lt.csv', 'release-notes-opensuse-leap_15_5-lt.csv', 'release-notes-opensuse-leap_15_6-lt.csv', 'release-notes-opensuse-glossary-lt.csv', 'release-notes-opensuse-master-lt.csv'] already up-to-date
# File being checked :  by_language\mk\release-notes-opensuse-leap-15_4-mk.csv
# ['release-notes-opensuse-leap-15_4-mk.csv', 'release-notes-opensuse-leap_15_5-mk.csv', 'release-notes-opensuse-leap_15_6-mk.csv', 'release-notes-opensuse-glossary-mk.csv', 'release-notes-opensuse-master-mk.csv'] already up-to-date
# File being checked :  by_language\ms\release-notes-opensuse-leap-15_2-ms.csv
# ['release-notes-opensuse-leap-15_2-ms.csv', 'release-notes-opensuse-leap-15_3-ms.csv', 'release-notes-opensuse-leap-15_4-ms.csv', 'release-notes-opensuse-leap_15_5-ms.csv', 'release-notes-opensuse-leap_15_6-ms.csv', 'release-notes-opensuse-glossary-ms.csv'] already up-to-date
# File being checked :  by_language\mr\release-notes-opensuse-leap-15_2-mr.csv
# ['release-notes-opensuse-leap-15_2-mr.csv', 'release-notes-opensuse-leap-15_3-mr.csv', 'release-notes-opensuse-leap-15_4-mr.csv', 'release-notes-opensuse-leap_15_5-mr.csv', 'release-notes-opensuse-leap_15_6-mr.csv', 'release-notes-opensuse-glossary-mr.csv', 'release-notes-opensuse-master-mr.csv'] already up-to-date
# File being checked :  by_language\nb\release-notes-opensuse-leap-15_2-nb.csv
# ['release-notes-opensuse-leap-15_2-nb.csv', 'release-notes-opensuse-leap-15_3-nb.csv', 'release-notes-opensuse-leap-15_4-nb.csv', 'release-notes-opensuse-leap_15_5-nb.csv', 'release-notes-opensuse-leap_15_6-nb.csv', 'release-notes-opensuse-glossary-nb.csv', 'release-notes-opensuse-master-nb.csv'] already up-to-date
# File being checked :  by_language\nn\release-notes-opensuse-leap-15_2-nn.csv
# ['release-notes-opensuse-leap-15_2-nn.csv', 'release-notes-opensuse-leap-15_3-nn.csv', 'release-notes-opensuse-leap-15_4-nn.csv', 'release-notes-opensuse-leap_15_5-nn.csv', 'release-notes-opensuse-leap_15_6-nn.csv', 'release-notes-opensuse-glossary-nn.csv', 'release-notes-opensuse-master-nn.csv'] already up-to-date
# File being checked :  by_language\fa\release-notes-opensuse-leap-15_2-fa.csv
# ['release-notes-opensuse-leap-15_2-fa.csv', 'release-notes-opensuse-leap-15_3-fa.csv', 'release-notes-opensuse-leap-15_4-fa.csv', 'release-notes-opensuse-leap_15_5-fa.csv', 'release-notes-opensuse-leap_15_6-fa.csv', 'release-notes-opensuse-glossary-fa.csv', 'release-notes-opensuse-master-fa.csv'] already up-to-date
# File being checked :  by_language\pl\release-notes-opensuse-leap-15_2-pl.csv
# ['release-notes-opensuse-leap-15_2-pl.csv', 'release-notes-opensuse-leap-15_3-pl.csv', 'release-notes-opensuse-leap-15_4-pl.csv', 'release-notes-opensuse-leap_15_5-pl.csv', 'release-notes-opensuse-leap_15_6-pl.csv', 'release-notes-opensuse-glossary-pl.csv', 'release-notes-opensuse-master-pl.csv'] already up-to-date
# File being checked :  by_language\pt\release-notes-opensuse-leap-15_2-pt.csv
# ['release-notes-opensuse-leap-15_2-pt.csv', 'release-notes-opensuse-leap-15_3-pt.csv', 'release-notes-opensuse-leap-15_4-pt.csv', 'release-notes-opensuse-leap_15_5-pt.csv', 'release-notes-opensuse-leap_15_6-pt.csv', 'release-notes-opensuse-glossary-pt.csv', 'release-notes-opensuse-master-pt.csv'] already up-to-date
# File being checked :  by_language\pt_BR\release-notes-opensuse-leap-15_2-pt_BR.csv
# ['release-notes-opensuse-leap-15_2-pt_BR.csv', 'release-notes-opensuse-leap-15_3-pt_BR.csv', 'release-notes-opensuse-leap-15_4-pt_BR.csv', 'release-notes-opensuse-leap_15_5-pt_BR.csv', 'release-notes-opensuse-leap_15_6-pt_BR.csv', 'release-notes-opensuse-glossary-pt_BR.csv', 'release-notes-opensuse-master-pt_BR.csv'] already up-to-date
# File being checked :  by_language\pa\release-notes-opensuse-leap-15_2-pa.csv
# ...
# Downloaded : by_language\tr\agama-agama-web-tr.csv
# File being checked :  by_language\uk\agama-glossary-uk.csv
# agama-glossary-uk.csv is empty
# Downloaded : by_language\uk\agama-agama-web-uk.csv
# File being checked :  by_language\af\suse-desktop-translations-main-af.csv
# Downloaded : by_language\af\suse-desktop-translations-main-af.csv
# suse-desktop-translations-glossary-af.csv is empty
# File being checked :  by_language\ar\suse-desktop-translations-main-ar.csv
# Downloaded : by_language\ar\suse-desktop-translations-main-ar.csv
# suse-desktop-translations-glossary-ar.csv is empty
# File being checked :  by_language\az\suse-desktop-translations-main-az.csv
# Downloaded : by_language\az\suse-desktop-translations-main-az.csv
# suse-desktop-translations-glossary-az.csv is empty
# File being checked :  by_language\eu\suse-desktop-translations-main-eu.csv
# Downloaded : by_language\eu\suse-desktop-translations-main-eu.csv
# suse-desktop-translations-glossary-eu.csv is empty
# File being checked :  by_language\be\suse-desktop-translations-main-be.csv
# Downloaded : by_language\be\suse-desktop-translations-main-be.csv
# suse-desktop-translations-glossary-be.csv is empty
# File being checked :  by_language\bn\suse-desktop-translations-main-bn.csv
# Downloaded : by_language\bn\suse-desktop-translations-main-bn.csv
# suse-desktop-translations-glossary-bn.csv is empty
# File being checked :  by_language\bs\suse-desktop-translations-main-bs.csv
# Downloaded : by_language\bs\suse-desktop-translations-main-bs.csv
# suse-desktop-translations-glossary-bs.csv is empty
# File being checked :  by_language\br\suse-desktop-translations-main-br.csv
# Downloaded : by_language\br\suse-desktop-translations-main-br.csv
# suse-desktop-translations-glossary-br.csv is empty
# File being checked :  by_language\bg\suse-desktop-translations-main-bg.csv
# Downloaded : by_language\bg\suse-desktop-translations-main-bg.csv
# suse-desktop-translations-glossary-bg.csv is empty
# File being checked :  by_language\ca\suse-desktop-translations-main-ca.csv
# Downloaded : by_language\ca\suse-desktop-translations-main-ca.csv
# suse-desktop-translations-glossary-ca.csv is empty
# File being checked :  by_language\zh_CN\suse-desktop-translations-main-zh_CN.csv
# Downloaded : by_language\zh_CN\suse-desktop-translations-main-zh_CN.csv
# suse-desktop-translations-glossary-zh_CN.csv is empty
# File being checked :  by_language\zh_TW\suse-desktop-translations-main-zh_TW.csv
# Downloaded : by_language\zh_TW\suse-desktop-translations-main-zh_TW.csv
# suse-desktop-translations-glossary-zh_TW.csv is empty
# File being checked :  by_language\hr\suse-desktop-translations-main-hr.csv
# Downloaded : by_language\hr\suse-desktop-translations-main-hr.csv
# suse-desktop-translations-glossary-hr.csv is empty
# File being checked :  by_language\cs\suse-desktop-translations-main-cs.csv
# Downloaded : by_language\cs\suse-desktop-translations-main-cs.csv
# suse-desktop-translations-glossary-cs.csv is empty
# File being checked :  by_language\da\suse-desktop-translations-main-da.csv
# Downloaded : by_language\da\suse-desktop-translations-main-da.csv
# suse-desktop-translations-glossary-da.csv is empty
# File being checked :  by_language\nl\suse-desktop-translations-main-nl.csv
# Downloaded : by_language\nl\suse-desktop-translations-main-nl.csv
# suse-desktop-translations-glossary-nl.csv is empty
# File being checked :  by_language\en_GB\suse-desktop-translations-main-en_GB.csv
# Downloaded : by_language\en_GB\suse-desktop-translations-main-en_GB.csv
# suse-desktop-translations-glossary-en_GB.csv is empty
# File being checked :  by_language\en_US\suse-desktop-translations-main-en_US.csv
# Downloaded : by_language\en_US\suse-desktop-translations-main-en_US.csv
# suse-desktop-translations-glossary-en_US.csv is empty
# File being checked :  by_language\eo\suse-desktop-translations-main-eo.csv
# Downloaded : by_language\eo\suse-desktop-translations-main-eo.csv
# suse-desktop-translations-glossary-eo.csv is empty
# File being checked :  by_language\et\suse-desktop-translations-main-et.csv
# Downloaded : by_language\et\suse-desktop-translations-main-et.csv
# suse-desktop-translations-glossary-et.csv is empty
# File being checked :  by_language\fi\suse-desktop-translations-main-fi.csv
# Downloaded : by_language\fi\suse-desktop-translations-main-fi.csv
# suse-desktop-translations-glossary-fi.csv is empty
# File being checked :  by_language\fr\suse-desktop-translations-main-fr.csv
# Downloaded : by_language\fr\suse-desktop-translations-main-fr.csv
# suse-desktop-translations-glossary-fr.csv is empty
# File being checked :  by_language\fy\suse-desktop-translations-main-fy.csv
# Downloaded : by_language\fy\suse-desktop-translations-main-fy.csv
# suse-desktop-translations-glossary-fy.csv is empty
# File being checked :  by_language\gl\suse-desktop-translations-main-gl.csv
# Downloaded : by_language\gl\suse-desktop-translations-main-gl.csv
# suse-desktop-translations-glossary-gl.csv is empty
# File being checked :  by_language\ka\suse-desktop-translations-main-ka.csv
# Downloaded : by_language\ka\suse-desktop-translations-main-ka.csv
# suse-desktop-translations-glossary-ka.csv is empty
# File being checked :  by_language\de\suse-desktop-translations-main-de.csv
# Downloaded : by_language\de\suse-desktop-translations-main-de.csv
# suse-desktop-translations-glossary-de.csv is empty
# File being checked :  by_language\nds\suse-desktop-translations-main-nds.csv
# Downloaded : by_language\nds\suse-desktop-translations-main-nds.csv
# suse-desktop-translations-glossary-nds.csv is empty
# File being checked :  by_language\el\suse-desktop-translations-main-el.csv
# Downloaded : by_language\el\suse-desktop-translations-main-el.csv
# suse-desktop-translations-glossary-el.csv is empty
# File being checked :  by_language\gu\suse-desktop-translations-main-gu.csv
# Downloaded : by_language\gu\suse-desktop-translations-main-gu.csv
# suse-desktop-translations-glossary-gu.csv is empty
# File being checked :  by_language\he\suse-desktop-translations-main-he.csv
# Downloaded : by_language\he\suse-desktop-translations-main-he.csv
# suse-desktop-translations-glossary-he.csv is empty
# File being checked :  by_language\hi\suse-desktop-translations-main-hi.csv
# Downloaded : by_language\hi\suse-desktop-translations-main-hi.csv
# suse-desktop-translations-glossary-hi.csv is empty
# File being checked :  by_language\hu\suse-desktop-translations-main-hu.csv
# Downloaded : by_language\hu\suse-desktop-translations-main-hu.csv
# suse-desktop-translations-glossary-hu.csv is empty
# File being checked :  by_language\is\suse-desktop-translations-main-is.csv
# Downloaded : by_language\is\suse-desktop-translations-main-is.csv
# suse-desktop-translations-glossary-is.csv is empty
# File being checked :  by_language\id\suse-desktop-translations-main-id.csv
# Downloaded : by_language\id\suse-desktop-translations-main-id.csv
# suse-desktop-translations-glossary-id.csv is empty
# File being checked :  by_language\ga\suse-desktop-translations-main-ga.csv
# Downloaded : by_language\ga\suse-desktop-translations-main-ga.csv
# suse-desktop-translations-glossary-ga.csv is empty
# File being checked :  by_language\it\suse-desktop-translations-main-it.csv
# Downloaded : by_language\it\suse-desktop-translations-main-it.csv
# suse-desktop-translations-glossary-it.csv is empty
# File being checked :  by_language\ja\suse-desktop-translations-main-ja.csv
# Downloaded : by_language\ja\suse-desktop-translations-main-ja.csv
# suse-desktop-translations-glossary-ja.csv is empty
# File being checked :  by_language\kab\suse-desktop-translations-main-kab.csv
# Downloaded : by_language\kab\suse-desktop-translations-main-kab.csv
# suse-desktop-translations-glossary-kab.csv is empty
# File being checked :  by_language\km\suse-desktop-translations-main-km.csv
# Downloaded : by_language\km\suse-desktop-translations-main-km.csv
# suse-desktop-translations-glossary-km.csv is empty
# File being checked :  by_language\rw\suse-desktop-translations-main-rw.csv
# Downloaded : by_language\rw\suse-desktop-translations-main-rw.csv
# suse-desktop-translations-glossary-rw.csv is empty
# File being checked :  by_language\ko\suse-desktop-translations-main-ko.csv
# Downloaded : by_language\ko\suse-desktop-translations-main-ko.csv
# suse-desktop-translations-glossary-ko.csv is empty
# File being checked :  by_language\ku\suse-desktop-translations-main-ku.csv
# Downloaded : by_language\ku\suse-desktop-translations-main-ku.csv
# suse-desktop-translations-glossary-ku.csv is empty
# File being checked :  by_language\lo\suse-desktop-translations-main-lo.csv
# Downloaded : by_language\lo\suse-desktop-translations-main-lo.csv
# suse-desktop-translations-glossary-lo.csv is empty
# File being checked :  by_language\lv\suse-desktop-translations-main-lv.csv
# Downloaded : by_language\lv\suse-desktop-translations-main-lv.csv
# suse-desktop-translations-glossary-lv.csv is empty
# File being checked :  by_language\lt\suse-desktop-translations-main-lt.csv
# Downloaded : by_language\lt\suse-desktop-translations-main-lt.csv
# suse-desktop-translations-glossary-lt.csv is empty
# File being checked :  by_language\mk\suse-desktop-translations-main-mk.csv
# Downloaded : by_language\mk\suse-desktop-translations-main-mk.csv
# suse-desktop-translations-glossary-mk.csv is empty
# File being checked :  by_language\ms\suse-desktop-translations-main-ms.csv
# Downloaded : by_language\ms\suse-desktop-translations-main-ms.csv
# suse-desktop-translations-glossary-ms.csv is empty
# File being checked :  by_language\mt\suse-desktop-translations-main-mt.csv
# Downloaded : by_language\mt\suse-desktop-translations-main-mt.csv
# suse-desktop-translations-glossary-mt.csv is empty
# File being checked :  by_language\mr\suse-desktop-translations-main-mr.csv
# Downloaded : by_language\mr\suse-desktop-translations-main-mr.csv
# suse-desktop-translations-glossary-mr.csv is empty
# File being checked :  by_language\mn\suse-desktop-translations-main-mn.csv
# Downloaded : by_language\mn\suse-desktop-translations-main-mn.csv
# suse-desktop-translations-glossary-mn.csv is empty
# File being checked :  by_language\nb\suse-desktop-translations-main-nb.csv
# Downloaded : by_language\nb\suse-desktop-translations-main-nb.csv
# suse-desktop-translations-glossary-nb.csv is empty
# File being checked :  by_language\nn\suse-desktop-translations-main-nn.csv
# Downloaded : by_language\nn\suse-desktop-translations-main-nn.csv
# suse-desktop-translations-glossary-nn.csv is empty
# File being checked :  by_language\nso\suse-desktop-translations-main-nso.csv
# Downloaded : by_language\nso\suse-desktop-translations-main-nso.csv
# suse-desktop-translations-glossary-nso.csv is empty
# File being checked :  by_language\fa\suse-desktop-translations-main-fa.csv
# Downloaded : by_language\fa\suse-desktop-translations-main-fa.csv
# suse-desktop-translations-glossary-fa.csv is empty
# File being checked :  by_language\pl\suse-desktop-translations-main-pl.csv
# Downloaded : by_language\pl\suse-desktop-translations-main-pl.csv
# suse-desktop-translations-glossary-pl.csv is empty
# File being checked :  by_language\pt\suse-desktop-translations-main-pt.csv
# Downloaded : by_language\pt\suse-desktop-translations-main-pt.csv
# suse-desktop-translations-glossary-pt.csv is empty
# File being checked :  by_language\pt_BR\suse-desktop-translations-main-pt_BR.csv
# Downloaded : by_language\pt_BR\suse-desktop-translations-main-pt_BR.csv
# suse-desktop-translations-glossary-pt_BR.csv is empty
# File being checked :  by_language\pa\suse-desktop-translations-main-pa.csv
# Downloaded : by_language\pa\suse-desktop-translations-main-pa.csv
# suse-desktop-translations-glossary-pa.csv is empty
# File being checked :  by_language\ro\suse-desktop-translations-main-ro.csv
# Downloaded : by_language\ro\suse-desktop-translations-main-ro.csv
# suse-desktop-translations-glossary-ro.csv is empty
# File being checked :  by_language\ru\suse-desktop-translations-main-ru.csv
# Downloaded : by_language\ru\suse-desktop-translations-main-ru.csv
# suse-desktop-translations-glossary-ru.csv is empty
# File being checked :  by_language\se\suse-desktop-translations-main-se.csv
# Downloaded : by_language\se\suse-desktop-translations-main-se.csv
# suse-desktop-translations-glossary-se.csv is empty
# File being checked :  by_language\sr\suse-desktop-translations-main-sr.csv
# Downloaded : by_language\sr\suse-desktop-translations-main-sr.csv
# suse-desktop-translations-glossary-sr.csv is empty
# File being checked :  by_language\sr@latin\suse-desktop-translations-main-sr@latin.csv
# Downloaded : by_language\sr@latin\suse-desktop-translations-main-sr@latin.csv
# suse-desktop-translations-glossary-sr@latin.csv is empty
# File being checked :  by_language\si\suse-desktop-translations-main-si.csv
# Downloaded : by_language\si\suse-desktop-translations-main-si.csv
# suse-desktop-translations-glossary-si.csv is empty
# File being checked :  by_language\sk\suse-desktop-translations-main-sk.csv
# Downloaded : by_language\sk\suse-desktop-translations-main-sk.csv
# suse-desktop-translations-glossary-sk.csv is empty
# File being checked :  by_language\sl\suse-desktop-translations-main-sl.csv
# Downloaded : by_language\sl\suse-desktop-translations-main-sl.csv
# suse-desktop-translations-glossary-sl.csv is empty
# File being checked :  by_language\es\suse-desktop-translations-main-es.csv
# Downloaded : by_language\es\suse-desktop-translations-main-es.csv
# suse-desktop-translations-glossary-es.csv is empty
# File being checked :  by_language\sv\suse-desktop-translations-main-sv.csv
# Downloaded : by_language\sv\suse-desktop-translations-main-sv.csv
# suse-desktop-translations-glossary-sv.csv is empty
# File being checked :  by_language\tg\suse-desktop-translations-main-tg.csv
# Downloaded : by_language\tg\suse-desktop-translations-main-tg.csv
# suse-desktop-translations-glossary-tg.csv is empty
# File being checked :  by_language\ta\suse-desktop-translations-main-ta.csv
# Downloaded : by_language\ta\suse-desktop-translations-main-ta.csv
# suse-desktop-translations-glossary-ta.csv is empty
# File being checked :  by_language\tt\suse-desktop-translations-main-tt.csv
# Downloaded : by_language\tt\suse-desktop-translations-main-tt.csv
# suse-desktop-translations-glossary-tt.csv is empty
# File being checked :  by_language\th\suse-desktop-translations-main-th.csv
# Downloaded : by_language\th\suse-desktop-translations-main-th.csv
# suse-desktop-translations-glossary-th.csv is empty
# File being checked :  by_language\tr\suse-desktop-translations-main-tr.csv
# Downloaded : by_language\tr\suse-desktop-translations-main-tr.csv
# suse-desktop-translations-glossary-tr.csv is empty
# File being checked :  by_language\uk\suse-desktop-translations-main-uk.csv
# Downloaded : by_language\uk\suse-desktop-translations-main-uk.csv
# suse-desktop-translations-glossary-uk.csv is empty
# File being checked :  by_language\uz\suse-desktop-translations-main-uz.csv
# Downloaded : by_language\uz\suse-desktop-translations-main-uz.csv
# suse-desktop-translations-glossary-uz.csv is empty
# File being checked :  by_language\vi\suse-desktop-translations-main-vi.csv
# Downloaded : by_language\vi\suse-desktop-translations-main-vi.csv
# suse-desktop-translations-glossary-vi.csv is empty
# File being checked :  by_language\wa\suse-desktop-translations-main-wa.csv
# Downloaded : by_language\wa\suse-desktop-translations-main-wa.csv
# suse-desktop-translations-glossary-wa.csv is empty
# File being checked :  by_language\cy\suse-desktop-translations-main-cy.csv
# Downloaded : by_language\cy\suse-desktop-translations-main-cy.csv
# suse-desktop-translations-glossary-cy.csv is empty
# File being checked :  by_language\xh\suse-desktop-translations-main-xh.csv
# Downloaded : by_language\xh\suse-desktop-translations-main-xh.csv
# suse-desktop-translations-glossary-xh.csv is empty
# File being checked :  by_language\zu\suse-desktop-translations-main-zu.csv
# Downloaded : by_language\zu\suse-desktop-translations-main-zu.csv
# suse-desktop-translations-glossary-zu.csv is empty
# File being checked :  by_language\ven\suse-desktop-translations-main-ven.csv
# Downloaded : by_language\ven\suse-desktop-translations-main-ven.csv
# suse-desktop-translations-glossary-ven.csv is empty
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Disconnecting...
# Done!
# 0

# %% [markdown]
# # Ubuntu Launchpad translations
# Ubuntu translations are available on Launchpad, that allows to download a .zip file with all translations. We will use this way to download them, and we will save the update time in case an update is required.
