# %% [markdown]
# # AI translation validation for Ubuntu - Data collection
#
# Use of Weblate API to automatically collect, store and update desired translations on the website Weblate.

# %% [markdown]
# # Importing annex useful functions

# %%
# Personal libraries
import importlib
import collector
from collector import Collector

# %%
importlib.reload(collector)
from collector import Collector
collector = Collector()

# %% [markdown]
# # Weblate projects
# Given a list of projects (or of keywords contained in the desired project names), one can download all its translations, in all languages using the function ``get_all_translations`` function :

# %%
# list of weblate apis and the associated desired project. when ALL : all the projects will be downloaded
wanted_projects = ["ubuntu", "debian"]
collector.get_all_translations("https://hosted.weblate.org/api/", "wlu_F8mRZZeJG9OZ4Y3NfGW6lakufaKJPu7IQFwI", wanted_projects)
# Out:
# You're using Windows.
# Performing system check...
# ###########################
#
# NordVPN installation check: ✓
# NordVPN service check: ✓
# Opening NordVPN app and disconnecting if necessary...
# NordVPN app launched: ✓
# #####################################
#
# You've entered a list of connection options. Checking list...
#
#
# Saving settings in project folder...
#
#
# Done!
#
# File being checked :  os_by_language\dataset\debian\debian-handbook.csv
# Downloaded : os_by_language\dataset\debian\debian-handbook.csv
#
#  https://hosted.weblate.org/api/projects/?page=2
# File being checked :  os_by_language\dataset\debian\debian-member-portfolio-service.csv
# Program interrupted by user.
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Disconnecting...

# %% [markdown]
# # openSUSE translations
# openSUSE uses its own translation website, but it is also based on the Weblate API. Hence, it is possible to quickly adapt the previous code to collect all the translation of the software, that are numerous.

# %%
# list of weblate apis and the associated desired project. when ALL : all the projects will be downloaded
wanted_os = ["ALL;openSUSE"]
collector.get_all_translations("https://l10n.opensuse.org/api/", "", wanted_os)
# Out:
# You're using Windows.
# Performing system check...
# ###########################
#
# NordVPN installation check: ✓
# NordVPN service check: ✓
# Opening NordVPN app and disconnecting if necessary...
# NordVPN app launched: ✓
# #####################################
#
# You've entered a list of connection options. Checking list...
#
#
# Saving settings in project folder...
#
#
# Done!
#
#
#  https://l10n.opensuse.org/api/projects/?page=2
#
#  https://l10n.opensuse.org/api/projects/?page=3
# File being checked :  os_by_language\dataset\openSUSE\search-o-o.csv
# Downloaded : os_by_language\dataset\openSUSE\search-o-o.csv
# File being checked :  os_by_language\dataset\openSUSE\uyuni.csv
# An error has occured : ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Trying to load saved settings...
# Saved settings loaded!
#
#
# Disconnecting...
# Traceback (most recent call last):
#   File "c:\Users\romai\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py", line 789, in urlopen
#     response = self._make_request(
#                ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\romai\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py", line 536, in _make_request
#     response = conn.getresponse()
#                ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\romai\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py", line 464, in getresponse
#     httplib_response = super().getresponse()
#                        ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\romai\AppData\Local\Programs\Python\Python312\Lib\http\client.py", line 1428, in getresponse
#     response.begin()
#   File "c:\Users\romai\AppData\Local\Programs\Python\Python312\Lib\http\client.py", line 331, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\romai\AppData\Local\Programs\Python\Python312\Lib\http\client.py", line 300, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\romai\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\adapters.py", line 667, in send
#     resp = conn.urlopen(
#            ^^^^^^^^^^^^^
#   File "c:\Users\romai\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py", line 843, in urlopen
#     retries = retries.increment(
#               ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\romai\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\util\retry.py", line 474, in increment
#     raise reraise(type(error), error, _stacktrace)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\romai\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\util\util.py", line 38, in reraise
#     raise value.with_traceback(tb)
#   File "c:\Users\romai\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py", line 789, in urlopen
#     response = self._make_request(
#                ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\romai\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py", line 536, in _make_request
#     response = conn.getresponse()
#                ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\romai\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py", line 464, in getresponse
#     httplib_response = super().getresponse()
#                        ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\romai\AppData\Local\Programs\Python\Python312\Lib\http\client.py", line 1428, in getresponse
#     response.begin()
#   File "c:\Users\romai\AppData\Local\Programs\Python\Python312\Lib\http\client.py", line 331, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\romai\AppData\Local\Programs\Python\Python312\Lib\http\client.py", line 300, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\romai\Desktop\Drive\My Drive\Master_Thesis_Canonical\0_project_pipeline\1_data_collection\collector.py", line 118, in get_all_translations
#     added_or_updated_files = self.update_file(languages, path)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\romai\Desktop\Drive\My Drive\Master_Thesis_Canonical\0_project_pipeline\1_data_collection\collector.py", line 202, in update_file
#     response = requests.get(download_url)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\romai\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\romai\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\romai\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\romai\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\romai\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\adapters.py", line 682, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %% [markdown]
# # Ubuntu Launchpad translations
# Ubuntu translations are available on Launchpad, that allows to download a .zip file with all translations. We will use this way to download them, and we will save the update time in case an update is required. <br>
# **Note :** the dataset could be extended with previous versions of Ubuntu, that are also available on Launchpad.

# %%
collector.get_ubuntu_translation("ubuntu-noble", "https://translations.launchpad.net/ubuntu/noble/+translations")

# %% [markdown]
# # Resetting metadata of the dataset if required
# Uncomment the desired action to perform and run the cell.

# %%
collector = Collector()
collector.empty_archive_files()
collector.empty_updated_files()
